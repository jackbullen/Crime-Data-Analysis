# %%
import numpy
import csv
import datetime as dt
import matplotlib.pyplot as plt
import collections as co
from operator import itemgetter

# %%
ls
# Out:
# Untitled.ipynb     incidents (1).csv

# %%
dat = []
with open('incidents (1).csv', newline='') as csvfile:
    spamreader1 = csv.reader(csvfile, delimiter=',', quotechar='|')
    for i,row in enumerate(spamreader1):
        
        if i==0:
            ids = row
            
        else:  
            di = dict()
            for j,ID in enumerate(ids):
                
                if ID=='reportedtime':
                    Date = row[j].split(' ')
                    di['date'] = Date
                    continue
                di[ID] = row[j]
            dat.append(di)

# %%
dat
# Out:
# [{'id': '4201201937861',
#   'file': '2019-37861',
#   'date': ['9/20/2019', '3:50:00', 'AM'],
#   'occurrencetype': 'Commercial Break and Enter',
#   'occurrencetypeid': '2120-01',
#   'crimetype': 'Break and Enter',
#   'crimetypeid': '1',
#   'crimecategory': 'Property Crime',
#   'crimecategoryid': '1',
#   'location': '23XX DORMAN RD',
#   'locationid': '39074',
#   'neighbourhood': 'Northfield',
#   'neighbourhoodid': '5',
#   'lat': '49.196446',
#   'long': '-123.985369'},
#  {'id': '4201201937089',
#   'file': '2019-37089',
#   'date': ['9/15/2019', '9:26:00', 'AM'],
#   'occurrencetype': 'Commercial Break and Enter',
#   'occurrencetypeid': '2120-01',
#   'crimetype': 'Break and Enter',
#   'crimetypeid': '1',
#   'crimecategory': 'Property Crime',
#   'crimecategoryid': '1',
#   'location': '23XX DORMAN RD',
#   'locationid': '39074',
#   'neighbourhood': 'Northfield',
#   'neighbourhoodid': '5',
#   'lat': '49.196446',
#   'long': '-123.985369'},
#  {'id': '4201201937051',
#   'file': '2019-37051',
#   'date': ['9/15/2019', '12:13:00', 'AM'],
#   'occurrencetype': 'Commercial Break and Enter',
#   'occurrencetypeid': '2120-01',
#   'crimetype': 'Break and Enter',
#   'crimetypeid': '1',
#   'crimecategory': 'Property Crime',
#   'crimecategoryid': '1',
#   'location': '23XX DORMAN RD',
#   'locationid': '39074',
#   'neighbourhood': 'Northfield',
#   'neighbourhoodid': '5',
#   'lat': '49.196446',
#   'long': '-123.985369'},
#  {'id': '4201201916068',
#   'file': '2019-16068',
#   'date': ['5/4/2019', '4:31:00', 'AM'],
#   'occurrencetype': 'Commercial Break and Enter',
#   'occurrencetypeid': '2120-01',
#   'crimetype': 'Break and Enter',
#   'crimetypeid': '1',
#   'crimecategory': 'Property Crime',
#   'crimecategoryid': '1',
#   'location': '1XX CHAPEL ST',
#   'locationid': '39444',
#   'neighbourhood': 'Downtown',
#   'neighbourhoodid': '2',
#   'lat': '49.168244',
#   'long': '-123.937903'},
#  {'id': '4201201914457',
#   'file': '2019-14457',
#   'date': ['4/24/2019', '6:28:00', 'AM'],
#   'occurrencetype': 'Commercial Break and Enter',
#   'occurrencetypeid': '2120-01',
#   'crimetype': 'Break and Enter',
#   'crimetypeid': '1',
#   'crimecategory': 'Property Crime',
#   'crimecategoryid': '1',
#   'location': '1XX CHAPEL ST',
#   'locationid': '39444',
#   'neighbourhood': 'Downtown',
#   'neighbourhoodid': '2',
#   'lat': '49.168244',
#   'long': '-123.937903'},
#  {'id': '4201201936250',
#   'file': '2019-36250',
#   'date': ['9/10/2019', '5:22:00', 'AM'],
#   'occurrencetype': 'Commercial Break and Enter',
#   'occurrencetypeid': '2120-01',
#   'crimetype': 'Break and Enter',
#   'crimetypeid': '1',
#   'crimecategory': 'Property Crime',
#   'crimecategoryid': '1',
#   'location': '1XX CLIFF ST',
#   'locationid': '39445',
#   'neighbourhood': 'Downtown',
#   'neighbourhoodid': '2',
#   'lat': '49.167938',
#   'long': '-123.939277'},
#  {'id': '4201201939282',
#   'file': '2019-39282',
#   'date': ['9/29/2019', '6:20:00', 'AM'],
#   'occurrencetype': 'Commercial Break and Enter',
#   'occurrencetypeid': '2120-01',
#   'crimetype': 'Break and Enter',
#   'crimetypeid': '1',
#   'crimecategory': 'Property Crime',
#   'crimecategoryid': '1',
#   'location': '1XX COMMERCIAL ST',
#   'locationid': '39448',
#   'neighbourhood': 'Downtown',
#   'neighbourhoodid': '2',
#   'lat': '49.166692',
#   'long': '-123.937104'},
#  {'id': '4201201940917',
#   'file': '2019-40917',
#   'date': ['10/9/2019', '10:03:00', 'PM'],
#   'occurrencetype': 'Commercial Break and Enter',
#   'occurrencetypeid': '2120-01',
#   'crimetype': 'Break and Enter',
#   'crimetypeid': '1',
#   'crimecategory': 'Property Crime',
#   'crimecategoryid': '1',
#   'location': '1XX TERMINAL AVE',
#   'locationid': '39466',
#   'neighbourhood': 'Downtown',
#   'neighbourhoodid': '2',
#   'lat': '49.167987',
#   'long': '-123.940035'},
#  {'id': '4201201932971',
#   'file': '2019-32971',
#   'date': ['8/19/2019', '10:00:00', 'PM'],
#   'occurrencetype': 'Commercial Break and Enter',
#   'occurrencetypeid': '2120-01',
#   'crimetype': 'Break and Enter',
#   'crimetypeid': '1',
#   'crimecategory': 'Property Crime',
#   'crimecategoryid': '1',
#   'location': '1XX TERMINAL AVE',
#   'locationid': '39467',
#   'neighbourhood': 'Downtown',
#   'neighbourhoodid': '2',
#   'lat': '49.168237',
#   'long': '-123.940353'},
#  {'id': '4201201938131',
#   'file': '2019-38131',
#   'date': ['9/21/2019', '5:30:00', 'PM'],
#   'occurrencetype': 'Commercial Break and Enter',
#   'occurrencetypeid': '2120-01',
#   'crimetype': 'Break and Enter',
#   'crimetypeid': '1',
#   'crimecategory': 'Property Crime',
#   'crimecategoryid': '1',
#   'location': '2XX COMMERCIAL ST',
#   'locationid': '39476',
#   'neighbourhood': 'Downtown',
#   'neighbourhoodid': '2',
#   'lat': '49.166692',
#   'long': '-123.937104'},
#  {'id': '4201201924191',
#   'file': '2019-24191',
#   'date': ['6/26/2019', '4:48:00', 'AM'],
#   'occurrencetype': 'Commercial Break and Enter',
#   'occurrencetypeid': '2120-01',
#   'crimetype': 'Break and Enter',
#   'crimetypeid': '1',
#   'crimecategory': 'Property Crime',
#   'crimecategoryid': '1',
#   'location': '2XX COMMERCIAL ST',
#   'locationid': '39476',
#   'neighbourhood': 'Downtown',
#   'neighbourhoodid': '2',
#   'lat': '49.166692',
#   'long': '-123.937104'},
#  {'id': '4201201923781',
#   'file': '2019-23781',
#   'date': ['6/22/2019', '9:00:00', 'PM'],
#   'occurrencetype': 'Commercial Break and Enter',
#   'occurrencetypeid': '2120-01',
#   'crimetype': 'Break and Enter',
#   'crimetypeid': '1',
#   'crimecategory': 'Property Crime',
#   'crimecategoryid': '1',
#   'location': '2XX COMMERCIAL ST',
#   'locationid': '39476',
#   'neighbourhood': 'Downtown',
#   'neighbourhoodid': '2',
#   'lat': '49.166692',
#   'long': '-123.937104'},
#  {'id': '4201201936600',
#   'file': '2019-36600',
#   'date': ['9/11/2019', '10:00:00', 'PM'],
#   'occurrencetype': 'Commercial Break and Enter',
#   'occurrencetypeid': '2120-01',
#   'crimetype': 'Break and Enter',
#   'crimetypeid': '1',
#   'crimecategory': 'Property Crime',
#   'crimecategoryid': '1',
#   'location': '2XX FRASER ST',
#   'locationid': '39478',
#   'neighbourhood': 'Downtown',
#   'neighbourhoodid': '2',
#   'lat': '49.166547',
#   'long': '-123.939971'},
#  {'id': '4201201930642',
#   'file': '2019-30642',
#   'date': ['8/5/2019', '9:41:00', 'AM'],
#   'occurrencetype': 'Commercial Break and Enter',
#   'occurrencetypeid': '2120-01',
#   'crimetype': 'Break and Enter',
#   'crimetypeid': '1',
#   'crimecategory': 'Property Crime',
#   'crimecategoryid': '1',
#   'location': '2XX MILTON ST',
#   'locationid': '39482',
#   'neighbourhood': 'Downtown',
#   'neighbourhoodid': '2',
#   'lat': '49.165511',
#   'long': '-123.94595'},
#  {'id': '4201201936008',
#   'file': '2019-36008',
#   'date': ['9/8/2019', '9:45:00', 'AM'],
#   'occurrencetype': 'Commercial Break and Enter',
#   'occurrencetypeid': '2120-01',
#   'crimetype': 'Break and Enter',
#   'crimetypeid': '1',
#   'crimecategory': 'Property Crime',
#   'crimecategoryid': '1',
#   'location': '2XX SELBY ST',
#   'locationid': '39485',
#   'neighbourhood': 'Downtown',
#   'neighbourhoodid': '2',
#   'lat': '49.166008',
#   'long': '-123.943109'},
#  {'id': '4201201931245',
#   'file': '2019-31245',
#   'date': ['8/8/2019', '11:50:00', 'PM'],
#   'occurrencetype': 'Commercial Break and Enter',
#   'occurrencetypeid': '2120-01',
#   'crimetype': 'Break and Enter',
#   'crimetypeid': '1',
#   'crimecategory': 'Property Crime',
#   'crimecategoryid': '1',
#   'location': '2XX WALLACE ST',
#   'locationid': '39489',
#   'neighbourhood': 'Downtown',
#   'neighbourhoodid': '2',
#   'lat': '49.166443',
#   'long': '-123.9408'},
#  {'id': '4201201928305',
#   'file': '2019-28305',
#   'date': ['7/22/2019', '5:41:00', 'AM'],
#   'occurrencetype': 'Commercial Break and Enter',
#   'occurrencetypeid': '2120-01',
#   'crimetype': 'Break and Enter',
#   'crimetypeid': '1',
#   'crimecategory': 'Property Crime',
#   'crimecategoryid': '1',
#   'location': '2XX WALLACE ST',
#   'locationid': '39489',
#   'neighbourhood': 'Downtown',
#   'neighbourhoodid': '2',
#   'lat': '49.166443',
#   'long': '-123.9408'},
#  {'id': '4201201922853',
#   'file': '2019-22853',
#   'date': ['6/17/2019', '9:29:00', 'PM'],
#   'occurrencetype': 'Commercial Break and Enter',
#   'occurrencetypeid': '2120-01',
#   'crimetype': 'Break and Enter',
#   'crimetypeid': '1',
#   'crimecategory': 'Property Crime',
#   'crimecategoryid': '1',
#   'location': '3XX CAMPBELL ST',
#   'locationid': '39496',
#   'neighbourhood': 'Downtown',
#   'neighbourhoodid': '2',
#   'lat': '49.168452',
#   'long': '-123.942301'},
#  {'id': '4201201937205',
#   'file': '2019-37205',
#   'date': ['9/16/2019', '4:42:00', 'AM'],
#   'occurrencetype': 'Commercial Break and Enter',
#   'occurrencetypeid': '2120-01',
#   'crimetype': 'Break and Enter',
#   'crimetypeid': '1',
#   'crimecategory': 'Property Crime',
#   'crimecategoryid': '1',
#   'location': '3XX FITZWILLIAM ST',
#   'locationid': '39498',
#   'neighbourhood': 'Downtown',
#   'neighbourhoodid': '2',
#   'lat': '49.165784',
#   'long': '-123.940365'},
#  {'id': '4201201928306',
#   'file': '2019-28306',
#   'date': ['7/22/2019', '5:48:00', 'AM'],
#   'occurrencetype': 'Commercial Break and Enter',
#   'occurrencetypeid': '2120-01',
#   'crimetype': 'Break and Enter',
#   'crimetypeid': '1',
#   'crimecategory': 'Property Crime',
#   'crimecategoryid': '1',
#   'location': '3XX FITZWILLIAM ST',
#   'locationid': '39498',
#   'neighbourhood': 'Downtown',
#   'neighbourhoodid': '2',
#   'lat': '49.165784',
#   'long': '-123.940365'},
#  {'id': '4201201927523',
#   'file': '2019-27523',
#   'date': ['7/17/2019', '4:22:00', 'AM'],
#   'occurrencetype': 'Commercial Break and Enter',
#   'occurrencetypeid': '2120-01',
#   'crimetype': 'Break and Enter',
#   'crimetypeid': '1',
#   'crimecategory': 'Property Crime',
#   'crimecategoryid': '1',
#   'location': '3XX FITZWILLIAM ST',
#   'locationid': '39498',
#   'neighbourhood': 'Downtown',
#   'neighbourhoodid': '2',
#   'lat': '49.165784',
#   'long': '-123.940365'},
#  {'id': '4201201915471',
#   'file': '2019-15471',
#   'date': ['4/30/2019', '11:55:00', 'AM'],
#   'occurrencetype': 'Commercial Break and Enter',
#   'occurrencetypeid': '2120-01',
#   'crimetype': 'Break and Enter',
#   'crimetypeid': '1',
#   'crimecategory': 'Property Crime',
#   'crimecategoryid': '1',
#   'location': '3XX FITZWILLIAM ST',
#   'locationid': '39498',
#   'neighbourhood': 'Downtown',
#   'neighbourhoodid': '2',
#   'lat': '49.165784',
#   'long': '-123.940365'},
#  {'id': '4201201931690',
#   'file': '2019-31690',
#   'date': ['8/12/2019', '1:52:00', 'AM'],
#   'occurrencetype': 'Commercial Break and Enter',
#   'occurrencetypeid': '2120-01',
#   'crimetype': 'Break and Enter',
#   'crimetypeid': '1',
#   'crimecategory': 'Property Crime',
#   'crimecategoryid': '1',
#   'location': '3XX SELBY ST',
#   'locationid': '39509',
#   'neighbourhood': 'Downtown',
#   'neighbourhoodid': '2',
#   'lat': '49.164258',
#   'long': '-123.942011'},
#  {'id': '4201201913326',
#   'file': '2019-13326',
#   'date': ['4/16/2019', '4:05:00', 'AM'],
#   'occurrencetype': 'Commercial Break and Enter',
#   'occurrencetypeid': '2120-01',
#   'crimetype': 'Break and Enter',
#   'crimetypeid': '1',
#   'crimecategory': 'Property Crime',
#   'crimecategoryid': '1',
#   'location': '3XX SELBY ST',
#   'locationid': '39509',
#   'neighbourhood': 'Downtown',
#   'neighbourhoodid': '2',
#   'lat': '49.164258',
#   'long': '-123.942011'},
#  {'id': '4201201913337',
#   'file': '2019-13337',
#   'date': ['4/15/2019', '10:00:00', 'PM'],
#   'occurrencetype': 'Commercial Break and Enter',
#   'occurrencetypeid': '2120-01',
#   'crimetype': 'Break and Enter',
#   'crimetypeid': '1',
#   'crimecategory': 'Property Crime',
#   'crimecategoryid': '1',
#   'location': '3XX SELBY ST',
#   'locationid': '39509',
#   'neighbourhood': 'Downtown',
#   'neighbourhoodid': '2',
#   'lat': '49.164258',
#   'long': '-123.942011'},
#  {'id': '4201201923592',
#   'file': '2019-23592',
#   'date': ['6/21/2019', '11:12:00', 'PM'],
#   'occurrencetype': 'Commercial Break and Enter',
#   'occurrencetypeid': '2120-01',
#   'crimetype': 'Break and Enter',
#   'crimetypeid': '1',
#   'crimecategory': 'Property Crime',
#   'crimecategoryid': '1',
#   'location': '3XX TERMINAL AVE',
#   'locationid': '39510',
#   'neighbourhood': 'Downtown',
#   'neighbourhoodid': '2',
#   'lat': '49.166042',
#   'long': '-123.938613'},
#  {'id': '4201201936613',
#   'file': '2019-36613',
#   'date': ['9/11/2019', '10:00:00', 'PM'],
#   'occurrencetype': 'Commercial Break and Enter',
#   'occurrencetypeid': '2120-01',
#   'crimetype': 'Break and Enter',
#   'crimetypeid': '1',
#   'crimecategory': 'Property Crime',
#   'crimecategoryid': '1',
#   'location': '3XX WALLACE ST',
#   'locationid': '39511',
#   'neighbourhood': 'Downtown',
#   'neighbourhoodid': '2',
#   'lat': '49.165238',
#   'long': '-123.939134'},
#  {'id': '4201201928699',
#   'file': '2019-28699',
#   'date': ['7/24/2019', '2:26:00', 'AM'],
#   'occurrencetype': 'Commercial Break and Enter',
#   'occurrencetypeid': '2120-01',
#   'crimetype': 'Break and Enter',
#   'crimetypeid': '1',
#   'crimecategory': 'Property Crime',
#   'crimecategoryid': '1',
#   'location': '3XX WALLACE ST',
#   'locationid': '39511',
#   'neighbourhood': 'Downtown',
#   'neighbourhoodid': '2',
#   'lat': '49.165238',
#   'long': '-123.939134'},
#  {'id': '4201201936249',
#   'file': '2019-36249',
#   'date': ['9/10/2019', '5:22:00', 'AM'],
#   'occurrencetype': 'Commercial Break and Enter',
#   'occurrencetypeid': '2120-01',
#   'crimetype': 'Break and Enter',
#   'crimetypeid': '1',
#   'crimecategory': 'Property Crime',
#   'crimecategoryid': '1',
#   'location': '3XX WESLEY ST',
#   'locationid': '39512',
#   'neighbourhood': 'Downtown',
#   'neighbourhoodid': '2',
#   'lat': '49.164671',
#   'long': '-123.940773'},
#  {'id': '4201201934846',
#   'file': '2019-34846',
#   'date': ['8/31/2019', '3:23:00', 'PM'],
#   'occurrencetype': 'Commercial Break and Enter',
#   'occurrencetypeid': '2120-01',
#   'crimetype': 'Break and Enter',
#   'crimetypeid': '1',
#   'crimecategory': 'Property Crime',
#   'crimecategoryid': '1',
#   'location': '3XX WESLEY ST',
#   'locationid': '39512',
#   'neighbourhood': 'Downtown',
#   'neighbourhoodid': '2',
#   'lat': '49.164671',
#   'long': '-123.940773'},
#  {'id': '4201201928307',
#   'file': '2019-28307',
#   'date': ['7/22/2019', '5:45:00', 'AM'],
#   'occurrencetype': 'Commercial Break and Enter',
#   'occurrencetypeid': '2120-01',
#   'crimetype': 'Break and Enter',
#   'crimetypeid': '1',
#   'crimecategory': 'Property Crime',
#   'crimecategoryid': '1',
#   'location': '3XX WESLEY ST',
#   'locationid': '39512',
#   'neighbourhood': 'Downtown',
#   'neighbourhoodid': '2',
#   'lat': '49.164671',
#   'long': '-123.940773'},
#  {'id': '4201201920356',
#   'file': '2019-20356',
#   'date': ['6/1/2019', '3:30:00', 'AM'],
#   'occurrencetype': 'Commercial Break and Enter',
#   'occurrencetypeid': '2120-01',
#   'crimetype': 'Break and Enter',
#   'crimetypeid': '1',
#   'crimecategory': 'Property Crime',
#   'crimecategoryid': '1',
#   'location': '3XX WESLEY ST',
#   'locationid': '39512',
#   'neighbourhood': 'Downtown',
#   'neighbourhoodid': '2',
#   'lat': '49.164671',
#   'long': '-123.940773'},
#  {'id': '4201201914704',
#   'file': '2019-14704',
#   'date': ['4/25/2019', '4:56:00', 'PM'],
#   'occurrencetype': 'Commercial Break and Enter',
#   'occurrencetypeid': '2120-01',
#   'crimetype': 'Break and Enter',
#   'crimetypeid': '1',
#   'crimecategory': 'Property Crime',
#   'crimecategoryid': '1',
#   'location': '3XX WESLEY ST',
#   'locationid': '39512',
#   'neighbourhood': 'Downtown',
#   'neighbourhoodid': '2',
#   'lat': '49.164671',
#   'long': '-123.940773'},
#  {'id': '4201201936112',
#   'file': '2019-36112',
#   'date': ['9/9/2019', '1:58:00', 'AM'],
#   'occurrencetype': 'Commercial Break and Enter',
#   'occurrencetypeid': '2120-01',
#   'crimetype': 'Break and Enter',
#   'crimetypeid': '1',
#   'crimecategory': 'Property Crime',
#   'crimecategoryid': '1',
#   'location': '4XX DUNSMUIR ST',
#   'locationid': '39520',
#   'neighbourhood': 'Downtown',
#   'neighbourhoodid': '2',
#   'lat': '49.163227',
#   'long': '-123.937694'},
#  {'id': '4201201931284',
#   'file': '2019-31284',
#   'date': ['8/8/2019', '10:00:00', 'PM'],
#   'occurrencetype': 'Commercial Break and Enter',
#   'occurrencetypeid': '2120-01',
#   'crimetype': 'Break and Enter',
#   'crimetypeid': '1',
#   'crimecategory': 'Property Crime',
#   'crimecategoryid': '1',
#   'location': '4XX FITZWILLIAM ST',
#   'locationid': '39522',
#   'neighbourhood': 'Downtown',
#   'neighbourhoodid': '2',
#   'lat': '49.165258',
#   'long': '-123.942483'},
#  {'id': '4201201923891',
#   'file': '2019-23891',
#   'date': ['6/24/2019', '4:39:00', 'AM'],
#   'occurrencetype': 'Commercial Break and Enter',
#   'occurrencetypeid': '2120-01',
#   'crimetype': 'Break and Enter',
#   'crimetypeid': '1',
#   'crimecategory': 'Property Crime',
#   'crimecategoryid': '1',
#   'location': '4XX FITZWILLIAM ST',
#   'locationid': '39523',
#   'neighbourhood': 'Downtown',
#   'neighbourhoodid': '2',
#   'lat': '49.165425',
#   'long': '-123.941808'},
#  {'id': '4201201914315',
#   'file': '2019-14315',
#   'date': ['4/23/2019', '2:51:00', 'AM'],
#   'occurrencetype': 'Commercial Break and Enter',
#   'occurrencetypeid': '2120-01',
#   'crimetype': 'Break and Enter',
#   'crimetypeid': '1',
#   'crimecategory': 'Property Crime',
#   'crimecategoryid': '1',
#   'location': '4XX FITZWILLIAM ST',
#   'locationid': '39524',
#   'neighbourhood': 'Downtown',
#   'neighbourhoodid': '2',
#   'lat': '49.165591',
#   'long': '-123.94114'},
#  {'id': '4201201936164',
#   'file': '2019-36164',
#   'date': ['9/9/2019', '4:34:00', 'AM'],
#   'occurrencetype': 'Commercial Break and Enter',
#   'occurrencetypeid': '2120-01',
#   'crimetype': 'Break and Enter',
#   'crimetypeid': '1',
#   'crimecategory': 'Property Crime',
#   'crimecategoryid': '1',
#   'location': '4XX WALLACE ST',
#   'locationid': '39534',
#   'neighbourhood': 'Downtown',
#   'neighbourhoodid': '2',
#   'lat': '49.164143',
#   'long': '-123.937148'},
#  {'id': '4201201931868',
#   'file': '2019-31868',
#   'date': ['8/13/2019', '9:34:00', 'AM'],
#   'occurrencetype': 'Commercial Break and Enter',
#   'occurrencetypeid': '2120-01',
#   'crimetype': 'Break and Enter',
#   'crimetypeid': '1',
#   'crimecategory': 'Property Crime',
#   'crimecategoryid': '1',
#   'location': '4XX WENTWORTH ST',
#   'locationid': '39535',
#   'neighbourhood': 'Downtown',
#   'neighbourhoodid': '2',
#   'lat': '49.16691',
#   'long': '-123.942868'},
#  {'id': '4201201913136',
#   'file': '2019-13136',
#   'date': ['4/14/2019', '7:00:00', 'AM'],
#   'occurrencetype': 'Commercial Break and Enter',
#   'occurrencetypeid': '2120-01',
#   'crimetype': 'Break and Enter',
#   'crimetypeid': '1',
#   'crimecategory': 'Property Crime',
#   'crimecategoryid': '1',
#   'location': '6XX COMOX RD',
#   'locationid': '39559',
#   'neighbourhood': 'Downtown',
#   'neighbourhoodid': '2',
#   'lat': '49.17033',
#   'long': '-123.946327'},
#  {'id': '4201201939171',
#   'file': '2019-39171',
#   'date': ['9/28/2019', '12:20:00', 'PM'],
#   'occurrencetype': 'Commercial Break and Enter',
#   'occurrencetypeid': '2120-01',
#   'crimetype': 'Break and Enter',
#   'crimetypeid': '1',
#   'crimecategory': 'Property Crime',
#   'crimecategoryid': '1',
#   'location': '6XX TERMINAL AVE',
#   'locationid': '39570',
#   'neighbourhood': 'Downtown',
#   'neighbourhoodid': '2',
#   'lat': '49.163785',
#   'long': '-123.934638'},
#  {'id': '4201201914069',
#   'file': '2019-14069',
#   'date': ['4/21/2019', '4:25:00', 'AM'],
#   'occurrencetype': 'Commercial Break and Enter',
#   'occurrencetypeid': '2120-01',
#   'crimetype': 'Break and Enter',
#   'crimetypeid': '1',
#   'crimecategory': 'Property Crime',
#   'crimecategoryid': '1',
#   'location': '6XX TERMINAL AVE',
#   'locationid': '39570',
#   'neighbourhood': 'Downtown',
#   'neighbourhoodid': '2',
#   'lat': '49.163785',
#   'long': '-123.934638'},
#  {'id': '4201201915115',
#   'file': '2019-15115',
#   'date': ['4/27/2019', '11:52:00', 'PM'],
#   'occurrencetype': 'Commercial Break and Enter',
#   'occurrencetypeid': '2120-01',
#   'crimetype': 'Break and Enter',
#   'crimetypeid': '1',
#   'crimecategory': 'Property Crime',
#   'crimecategoryid': '1',
#   'location': 'FRANKLYN ST / ROBSON ST',
#   'locationid': '39610',
#   'neighbourhood': 'Downtown',
#   'neighbourhoodid': '2',
#   'lat': '49.164189',
#   'long': '-123.939215'},
#  {'id': '4201201915582',
#   'file': '2019-15582',
#   'date': ['5/1/2019', '6:58:00', 'AM'],
#   'occurrencetype': 'Commercial Break and Enter',
#   'occurrencetypeid': '2120-01',
#   'crimetype': 'Break and Enter',
#   'crimetypeid': '1',
#   'crimecategory': 'Property Crime',
#   'crimecategoryid': '1',
#   'location': 'X TERMINAL AVE N',
#   'locationid': '39651',
#   'neighbourhood': 'Downtown',
#   'neighbourhoodid': '2',
#   'lat': '49.170357',
#   'long': '-123.940992'},
#  {'id': '4201201934895',
#   'file': '2019-34895',
#   'date': ['8/31/2019', '11:34:00', 'PM'],
#   'occurrencetype': 'Commercial Break and Enter',
#   'occurrencetypeid': '2120-01',
#   'crimetype': 'Break and Enter',
#   'crimetypeid': '1',
#   'crimecategory': 'Property Crime',
#   'crimecategoryid': '1',
#   'location': 'XX CHAPEL ST',
#   'locationid': '39664',
#   'neighbourhood': 'Downtown',
#   'neighbourhoodid': '2',
#   'lat': '49.168244',
#   'long': '-123.937903'},
#  {'id': '4201201940212',
#   'file': '2019-40212',
#   'date': ['10/5/2019', '5:30:00', 'AM'],
#   'occurrencetype': 'Commercial Break and Enter',
#   'occurrencetypeid': '2120-01',
#   'crimetype': 'Break and Enter',
#   'crimetypeid': '1',
#   'crimecategory': 'Property Crime',
#   'crimecategoryid': '1',
#   'location': 'XX CLIFF ST',
#   'locationid': '39666',
#   'neighbourhood': 'Downtown',
#   'neighbourhoodid': '2',
#   'lat': '49.169477',
#   'long': '-123.939452'},
#  {'id': '4201201936120',
#   'file': '2019-36120',
#   'date': ['9/9/2019', '8:26:00', 'AM'],
#   'occurrencetype': 'Commercial Break and Enter',
#   'occurrencetypeid': '2120-01',
#   'crimetype': 'Break and Enter',
#   'crimetypeid': '1',
#   'crimecategory': 'Property Crime',
#   'crimecategoryid': '1',
#   'location': 'XX CLIFF ST',
#   'locationid': '39666',
#   'neighbourhood': 'Downtown',
#   'neighbourhoodid': '2',
#   'lat': '49.169477',
#   'long': '-123.939452'},
#  {'id': '4201201928756',
#   'file': '2019-28756',
#   'date': ['7/24/2019', '2:32:00', 'PM'],
#   'occurrencetype': 'Commercial Break and Enter',
#   'occurrencetypeid': '2120-01',
#   'crimetype': 'Break and Enter',
#   'crimetypeid': '1',
#   'crimecategory': 'Property Crime',
#   'crimecategoryid': '1',
#   'location': 'XX CLIFF ST',
#   'locationid': '39666',
#   'neighbourhood': 'Downtown',
#   'neighbourhoodid': '2',
#   'lat': '49.169477',
#   'long': '-123.939452'},
#  {'id': '4201201928472',
#   'file': '2019-28472',
#   'date': ['7/23/2019', '4:30:00', 'AM'],
#   'occurrencetype': 'Commercial Break and Enter',
#   'occurrencetypeid': '2120-01',
#   'crimetype': 'Break and Enter',
#   'crimetypeid': '1',
#   'crimecategory': 'Property Crime',
#   'crimecategoryid': '1',
#   'location': 'XX CLIFF ST',
#   'locationid': '39666',
#   'neighbourhood': 'Downtown',
#   'neighbourhoodid': '2',
#   'lat': '49.169477',
#   'long': '-123.939452'},
#  {'id': '4201201922705',
#   'file': '2019-22705',
#   'date': ['6/17/2019', '12:58:00', 'AM'],
#   'occurrencetype': 'Commercial Break and Enter',
#   'occurrencetypeid': '2120-01',
#   'crimetype': 'Break and Enter',
#   'crimetypeid': '1',
#   'crimecategory': 'Property Crime',
#   'crimecategoryid': '1',
#   'location': 'XX CLIFF ST',
#   'locationid': '39666',
#   'neighbourhood': 'Downtown',
#   'neighbourhoodid': '2',
#   'lat': '49.169477',
#   'long': '-123.939452'},
#  {'id': '4201201922428',
#   'file': '2019-22428',
#   'date': ['6/15/2019', '4:09:00', 'AM'],
#   'occurrencetype': 'Commercial Break and Enter',
#   'occurrencetypeid': '2120-01',
#   'crimetype': 'Break and Enter',
#   'crimetypeid': '1',
#   'crimecategory': 'Property Crime',
#   'crimecategoryid': '1',
#   'location': 'XX CLIFF ST',
#   'locationid': '39666',
#   'neighbourhood': 'Downtown',
#   'neighbourhoodid': '2',
#   'lat': '49.169477',
#   'long': '-123.939452'},
#  {'id': '4201201920959',
#   'file': '2019-20959',
#   'date': ['6/5/2019', '7:40:00', 'PM'],
#   'occurrencetype': 'Commercial Break and Enter',
#   'occurrencetypeid': '2120-01',
#   'crimetype': 'Break and Enter',
#   'crimetypeid': '1',
#   'crimecategory': 'Property Crime',
#   'crimecategoryid': '1',
#   'location': 'XX CLIFF ST',
#   'locationid': '39666',
#   'neighbourhood': 'Downtown',
#   'neighbourhoodid': '2',
#   'lat': '49.169477',
#   'long': '-123.939452'},
#  {'id': '4201201915810',
#   'file': '2019-15810',
#   'date': ['5/2/2019', '1:50:00', 'PM'],
#   'occurrencetype': 'Commercial Break and Enter',
#   'occurrencetypeid': '2120-01',
#   'crimetype': 'Break and Enter',
#   'crimetypeid': '1',
#   'crimecategory': 'Property Crime',
#   'crimecategoryid': '1',
#   'location': 'XX CLIFF ST',
#   'locationid': '39666',
#   'neighbourhood': 'Downtown',
#   'neighbourhoodid': '2',
#   'lat': '49.169477',
#   'long': '-123.939452'},
#  {'id': '4201201936722',
#   'file': '2019-36722',
#   'date': ['9/13/2019', '1:41:00', 'AM'],
#   'occurrencetype': 'Commercial Break and Enter',
#   'occurrencetypeid': '2120-01',
#   'crimetype': 'Break and Enter',
#   'crimetypeid': '1',
#   'crimecategory': 'Property Crime',
#   'crimecategoryid': '1',
#   'location': 'XX COMMERCIAL ST',
#   'locationid': '39668',
#   'neighbourhood': 'Downtown',
#   'neighbourhoodid': '2',
#   'lat': '49.165345',
#   'long': '-123.936851'},
#  {'id': '4201201934613',
#   'file': '2019-34613',
#   'date': ['8/30/2019', '9:04:00', 'AM'],
#   'occurrencetype': 'Commercial Break and Enter',
#   'occurrencetypeid': '2120-01',
#   'crimetype': 'Break and Enter',
#   'crimetypeid': '1',
#   'crimecategory': 'Property Crime',
#   'crimecategoryid': '1',
#   'location': 'XX COMMERCIAL ST',
#   'locationid': '39668',
#   'neighbourhood': 'Downtown',
#   'neighbourhoodid': '2',
#   'lat': '49.165345',
#   'long': '-123.936851'},
#  {'id': '4201201931997',
#   'file': '2019-31997',
#   'date': ['8/14/2019', '1:18:00', 'AM'],
#   'occurrencetype': 'Commercial Break and Enter',
#   'occurrencetypeid': '2120-01',
#   'crimetype': 'Break and Enter',
#   'crimetypeid': '1',
#   'crimecategory': 'Property Crime',
#   'crimecategoryid': '1',
#   'location': 'XX FRONT ST',
#   'locationid': '39671',
#   'neighbourhood': 'Downtown',
#   'neighbourhoodid': '2',
#   'lat': '49.167227',
#   'long': '-123.935998'},
#  {'id': '4201201925784',
#   'file': '2019-25784',
#   'date': ['7/6/2019', '5:48:00', 'AM'],
#   'occurrencetype': 'Commercial Break and Enter',
#   'occurrencetypeid': '2120-01',
#   'crimetype': 'Break and Enter',
#   'crimetypeid': '1',
#   'crimecategory': 'Property Crime',
#   'crimecategoryid': '1',
#   'location': 'XX FRONT ST',
#   'locationid': '39671',
#   'neighbourhood': 'Downtown',
#   'neighbourhoodid': '2',
#   'lat': '49.167227',
#   'long': '-123.935998'},
#  {'id': '4201201918505',
#   'file': '2019-18505',
#   'date': ['5/17/2019', '10:00:00', 'PM'],
#   'occurrencetype': 'Commercial Break and Enter',
#   'occurrencetypeid': '2120-01',
#   'crimetype': 'Break and Enter',
#   'crimetypeid': '1',
#   'crimecategory': 'Property Crime',
#   'crimecategoryid': '1',
#   'location': 'XX FRONT ST',
#   'locationid': '39671',
#   'neighbourhood': 'Downtown',
#   'neighbourhoodid': '2',
#   'lat': '49.167227',
#   'long': '-123.935998'},
#  {'id': '4201201935987',
#   'file': '2019-35987',
#   'date': ['9/8/2019', '3:50:00', 'AM'],
#   'occurrencetype': 'Commercial Break and Enter',
#   'occurrencetypeid': '2120-01',
#   'crimetype': 'Break and Enter',
#   'crimetypeid': '1',
#   'crimecategory': 'Property Crime',
#   'crimecategoryid': '1',
#   'location': 'XX FRONT ST',
#   'locationid': '39672',
#   'neighbourhood': 'Downtown',
#   'neighbourhoodid': '2',
#   'lat': '49.169009',
#   'long': '-123.937177'},
#  {'id': '4201201920337',
#   'file': '2019-20337',
#   'date': ['6/1/2019', '11:29:00', 'AM'],
#   'occurrencetype': 'Commercial Break and Enter',
#   'occurrencetypeid': '2120-01',
#   'crimetype': 'Break and Enter',
#   'crimetypeid': '1',
#   'crimecategory': 'Property Crime',
#   'crimecategoryid': '1',
#   'location': 'XX LOIS LANE',
#   'locationid': '39677',
#   'neighbourhood': 'Downtown',
#   'neighbourhoodid': '2',
#   'lat': '49.163889',
#   'long': '-123.935748'},
#  {'id': '4201201920305',
#   'file': '2019-20305',
#   'date': ['6/1/2019', '4:10:00', 'AM'],
#   'occurrencetype': 'Commercial Break and Enter',
#   'occurrencetypeid': '2120-01',
#   'crimetype': 'Break and Enter',
#   'crimetypeid': '1',
#   'crimecategory': 'Property Crime',
#   'crimecategoryid': '1',
#   'location': 'XX LOIS LANE',
#   'locationid': '39677',
#   'neighbourhood': 'Downtown',
#   'neighbourhoodid': '2',
#   'lat': '49.163889',
#   'long': '-123.935748'},
#  {'id': '4201201913639',
#   'file': '2019-13639',
#   'date': ['4/17/2019', '5:00:00', 'PM'],
#   'occurrencetype': 'Commercial Break and Enter',
#   'occurrencetypeid': '2120-01',
#   'crimetype': 'Break and Enter',
#   'crimetypeid': '1',
#   'crimecategory': 'Property Crime',
#   'crimecategoryid': '1',
#   'location': 'XX LOIS LANE',
#   'locationid': '39677',
#   'neighbourhood': 'Downtown',
#   'neighbourhoodid': '2',
#   'lat': '49.163889',
#   'long': '-123.935748'},
#  {'id': '4201201934001',
#   'file': '2019-34001',
#   'date': ['8/26/2019', '12:43:00', 'PM'],
#   'occurrencetype': 'Commercial Break and Enter',
#   'occurrencetypeid': '2120-01',
#   'crimetype': 'Break and Enter',
#   'crimetypeid': '1',
#   'crimecategory': 'Property Crime',
#   'crimecategoryid': '1',
#   'location': 'XX NICOL ST',
#   'locationid': '39680',
#   'neighbourhood': 'Downtown',
#   'neighbourhoodid': '2',
#   'lat': '49.163111',
#   'long': '-123.933982'},
#  {'id': '4201201926003',
#   'file': '2019-26003',
#   'date': ['7/7/2019', '8:39:00', 'PM'],
#   'occurrencetype': 'Commercial Break and Enter',
#   'occurrencetypeid': '2120-01',
#   'crimetype': 'Break and Enter',
#   'crimetypeid': '1',
#   'crimecategory': 'Property Crime',
#   'crimecategoryid': '1',
#   'location': 'XX PRIDEAUX ST',
#   'locationid': '39685',
#   'neighbourhood': 'Downtown',
#   'neighbourhoodid': '2',
#   'lat': '49.171425',
#   'long': '-123.945796'},
#  {'id': '4201201922246',
#   'file': '2019-22246',
#   'date': ['6/14/2019', '3:32:00', 'AM'],
#   'occurrencetype': 'Commercial Break and Enter',
#   'occurrencetypeid': '2120-01',
#   'crimetype': 'Break and Enter',
#   'crimetypeid': '1',
#   'crimecategory': 'Property Crime',
#   'crimecategoryid': '1',
#   'location': 'XX PRIDEAUX ST',
#   'locationid': '39685',
#   'neighbourhood': 'Downtown',
#   'neighbourhoodid': '2',
#   'lat': '49.171425',
#   'long': '-123.945796'},
#  {'id': '4201201938272',
#   'file': '2019-38272',
#   'date': ['9/22/2019', '10:36:00', 'PM'],
#   'occurrencetype': 'Commercial Break and Enter',
#   'occurrencetypeid': '2120-01',
#   'crimetype': 'Break and Enter',
#   'crimetypeid': '1',
#   'crimecategory': 'Property Crime',
#   'crimecategoryid': '1',
#   'location': 'XX ROBARTS ST',
#   'locationid': '39686',
#   'neighbourhood': 'Downtown',
#   'neighbourhoodid': '2',
#   'lat': '49.161488',
#   'long': '-123.935455'},
#  {'id': '4201201914070',
#   'file': '2019-14070',
#   'date': ['4/21/2019', '5:13:00', 'AM'],
#   'occurrencetype': 'Commercial Break and Enter',
#   'occurrencetypeid': '2120-01',
#   'crimetype': 'Break and Enter',
#   'crimetypeid': '1',
#   'crimecategory': 'Property Crime',
#   'crimecategoryid': '1',
#   'location': 'XX SKINNER ST',
#   'locationid': '39688',
#   'neighbourhood': 'Downtown',
#   'neighbourhoodid': '2',
#   'lat': '49.168832',
#   'long': '-123.93869'},
#  {'id': '4201201936127',
#   'file': '2019-36127',
#   'date': ['9/7/2019', '5:42:00', 'PM'],
#   'occurrencetype': 'Commercial Break and Enter',
#   'occurrencetypeid': '2120-01',
#   'crimetype': 'Break and Enter',
#   'crimetypeid': '1',
#   'crimecategory': 'Property Crime',
#   'crimecategoryid': '1',
#   'location': 'XX VICTORIA CRES',
#   'locationid': '39689',
#   'neighbourhood': 'Downtown',
#   'neighbourhoodid': '2',
#   'lat': '49.163415',
#   'long': '-123.935463'},
#  {'id': '4201201913091',
#   'file': '2019-13091',
#   'date': ['4/13/2019', '9:00:00', 'PM'],
#   'occurrencetype': 'Commercial Break and Enter',
#   'occurrencetypeid': '2120-01',
#   'crimetype': 'Break and Enter',
#   'crimetypeid': '1',
#   'crimecategory': 'Property Crime',
#   'crimecategoryid': '1',
#   'location': 'XX VICTORIA CRES',
#   'locationid': '39689',
#   'neighbourhood': 'Downtown',
#   'neighbourhoodid': '2',
#   'lat': '49.163415',
#   'long': '-123.935463'},
#  {'id': '4201201916600',
#   'file': '2019-16600',
#   'date': ['5/7/2019', '10:00:00', 'PM'],
#   'occurrencetype': 'Commercial Break and Enter',
#   'occurrencetypeid': '2120-01',
#   'crimetype': 'Break and Enter',
#   'crimetypeid': '1',
#   'crimecategory': 'Property Crime',
#   'crimecategoryid': '1',
#   'location': '28XX NORWELL DR',
#   'locationid': '39743',
#   'neighbourhood': 'Departure Bay',
#   'neighbourhoodid': '3',
#   'lat': '49.205157',
#   'long': '-124.0015'},
#  {'id': '4201201913119',
#   'file': '2019-13119',
#   'date': ['4/14/2019', '3:37:00', 'PM'],
#   'occurrencetype': 'Commercial Break and Enter',
#   'occurrencetypeid': '2120-01',
#   'crimetype': 'Break and Enter',
#   'crimetypeid': '1',
#   'crimecategory': 'Property Crime',
#   'crimecategoryid': '1',
#   'location': '16XX MOREY RD',
#   'locationid': '39815',
#   'neighbourhood': 'Northfield',
#   'neighbourhoodid': '5',
#   'lat': '49.177324',
#   'long': '-123.974629'},
#  {'id': '4201201928189',
#   'file': '2019-28189',
#   'date': ['7/21/2019', '8:27:00', 'AM'],
#   'occurrencetype': 'Commercial Break and Enter',
#   'occurrencetypeid': '2120-01',
#   'crimetype': 'Break and Enter',
#   'crimetypeid': '1',
#   'crimecategory': 'Property Crime',
#   'crimecategoryid': '1',
#   'location': '16XX NORTHFIELD RD',
#   'locationid': '39817',
#   'neighbourhood': 'Northfield',
#   'neighbourhoodid': '5',
#   'lat': '49.191928',
#   'long': '-123.975018'},
#  {'id': '4201201929001',
#   'file': '2019-29001',
#   'date': ['7/26/2019', '1:24:00', 'AM'],
#   'occurrencetype': 'Commercial Break and Enter',
#   'occurrencetypeid': '2120-01',
#   'crimetype': 'Break and Enter',
#   'crimetypeid': '1',
#   'crimecategory': 'Property Crime',
#   'crimecategoryid': '1',
#   'location': '17XX KIDSON RD',
#   'locationid': '39828',
#   'neighbourhood': 'Northfield',
#   'neighbourhoodid': '5',
#   'lat': '49.194368',
#   'long': '-123.978209'},
#  {'id': '4201201916331',
#   'file': '2019-16331',
#   'date': ['5/6/2019', '1:28:00', 'AM'],
#   'occurrencetype': 'Commercial Break and Enter',
#   'occurrencetypeid': '2120-01',
#   'crimetype': 'Break and Enter',
#   'crimetypeid': '1',
#   'crimecategory': 'Property Crime',
#   'crimecategoryid': '1',
#   'location': '18XX BOWEN RD',
#   'locationid': '39835',
#   'neighbourhood': 'Northfield',
#   'neighbourhoodid': '5',
#   'lat': '49.182886',
#   'long': '-123.98155'},
#  {'id': '4201201925121',
#   'file': '2019-25121',
#   'date': ['6/28/2019', '3:30:00', 'PM'],
#   'occurrencetype': 'Commercial Break and Enter',
#   'occurrencetypeid': '2120-01',
#   'crimetype': 'Break and Enter',
#   'crimetypeid': '1',
#   'crimecategory': 'Property Crime',
#   'crimecategoryid': '1',
#   'location': '18XX BOXWOOD RD',
#   'locationid': '39837',
#   'neighbourhood': 'Northfield',
#   'neighbourhoodid': '5',
#   'lat': '49.182803',
#   'long': '-123.985638'},
#  {'id': '4201201913100',
#   'file': '2019-13100',
#   'date': ['4/13/2019', '10:00:00', 'PM'],
#   'occurrencetype': 'Commercial Break and Enter',
#   'occurrencetypeid': '2120-01',
#   'crimetype': 'Break and Enter',
#   'crimetypeid': '1',
#   'crimecategory': 'Property Crime',
#   'crimecategoryid': '1',
#   'location': '18XX DUFFERIN CRES',
#   'locationid': '39838',
#   'neighbourhood': 'Northfield',
#   'neighbourhoodid': '5',
#   'lat': '49.183343',
#   'long': '-123.983908'},
#  {'id': '4201201932657',
#   'file': '2019-32657',
#   'date': ['8/18/2019', '8:16:00', 'AM'],
#   'occurrencetype': 'Commercial Break and Enter',
#   'occurrencetypeid': '2120-01',
#   'crimetype': 'Break and Enter',
#   'crimetypeid': '1',
#   'crimecategory': 'Property Crime',
#   'crimecategoryid': '1',
#   'location': '18XX EAST WELLINGTON RD',
#   'locationid': '39840',
#   'neighbourhood': 'Northfield',
#   'neighbourhoodid': '5',
#   'lat': '49.180294',
#   'long': '-123.981676'},
#  {'id': '4201201930117',
#   'file': '2019-30117',
#   'date': ['7/31/2019', '9:00:00', 'PM'],
#   'occurrencetype': 'Commercial Break and Enter',
#   'occurrencetypeid': '2120-01',
#   'crimetype': 'Break and Enter',
#   'crimetypeid': '1',
#   'crimecategory': 'Property Crime',
#   'crimecategoryid': '1',
#   'location': '18XX EAST WELLINGTON RD',
#   'locationid': '39840',
#   'neighbourhood': 'Northfield',
#   'neighbourhoodid': '5',
#   'lat': '49.180294',
#   'long': '-123.981676'},
#  {'id': '4201201920612',
#   'file': '2019-20612',
#   'date': ['6/3/2019', '1:09:00', 'PM'],
#   'occurrencetype': 'Commercial Break and Enter',
#   'occurrencetypeid': '2120-01',
#   'crimetype': 'Break and Enter',
#   'crimetypeid': '1',
#   'crimecategory': 'Property Crime',
#   'crimecategoryid': '1',
#   'location': '18XX EAST WELLINGTON RD',
#   'locationid': '39840',
#   'neighbourhood': 'Northfield',
#   'neighbourhoodid': '5',
#   'lat': '49.180294',
#   'long': '-123.981676'},
#  {'id': '4201201927354',
#   'file': '2019-27354',
#   'date': ['7/16/2019', '2:15:00', 'AM'],
#   'occurrencetype': 'Commercial Break and Enter',
#   'occurrencetypeid': '2120-01',
#   'crimetype': 'Break and Enter',
#   'crimetypeid': '1',
#   'crimecategory': 'Property Crime',
#   'crimecategoryid': '1',
#   'location': '19XX BOWEN RD',
#   'locationid': '39851',
#   'neighbourhood': 'Northfield',
#   'neighbourhoodid': '5',
#   'lat': '49.185887',
#   'long': '-123.984181'},
#  {'id': '4201201923407',
#   'file': '2019-23407',
#   'date': ['6/21/2019', '12:46:00', 'AM'],
#   'occurrencetype': 'Commercial Break and Enter',
#   'occurrencetypeid': '2120-01',
#   'crimetype': 'Break and Enter',
#   'crimetypeid': '1',
#   'crimecategory': 'Property Crime',
#   'crimecategoryid': '1',
#   'location': '19XX BOWEN RD',
#   'locationid': '39851',
#   'neighbourhood': 'Northfield',
#   'neighbourhoodid': '5',
#   'lat': '49.185887',
#   'long': '-123.984181'},
#  {'id': '4201201918394',
#   'file': '2019-18394',
#   'date': ['5/20/2019', '8:28:00', 'AM'],
#   'occurrencetype': 'Commercial Break and Enter',
#   'occurrencetypeid': '2120-01',
#   'crimetype': 'Break and Enter',
#   'crimetypeid': '1',
#   'crimecategory': 'Property Crime',
#   'crimecategoryid': '1',
#   'location': '19XX BOWEN RD',
#   'locationid': '39851',
#   'neighbourhood': 'Northfield',
#   'neighbourhoodid': '5',
#   'lat': '49.185887',
#   'long': '-123.984181'},
#  {'id': '4201201922636',
#   'file': '2019-22636',
#   'date': ['6/14/2019', '6:00:00', 'PM'],
#   'occurrencetype': 'Commercial Break and Enter',
#   'occurrencetypeid': '2120-01',
#   'crimetype': 'Break and Enter',
#   'crimetypeid': '1',
#   'crimecategory': 'Property Crime',
#   'crimecategoryid': '1',
#   'location': '19XX BOXWOOD RD',
#   'locationid': '39853',
#   'neighbourhood': 'Northfield',
#   'neighbourhoodid': '5',
#   'lat': '49.184226',
#   'long': '-123.986597'},
#  {'id': '4201201931846',
#   'file': '2019-31846',
#   'date': ['8/13/2019', '6:54:00', 'AM'],
#   'occurrencetype': 'Commercial Break and Enter',
#   'occurrencetypeid': '2120-01',
#   'crimetype': 'Break and Enter',
#   'crimetypeid': '1',
#   'crimecategory': 'Property Crime',
#   'crimecategoryid': '1',
#   'location': '19XX EAST WELLINGTON RD',
#   'locationid': '39855',
#   'neighbourhood': 'Northfield',
#   'neighbourhoodid': '5',
#   'lat': '49.180103',
#   'long': '-123.983575'},
#  {'id': '4201201924522',
#   'file': '2019-24522',
#   'date': ['6/28/2019', '3:54:00', 'AM'],
#   'occurrencetype': 'Commercial Break and Enter',
#   'occurrencetypeid': '2120-01',
#   'crimetype': 'Break and Enter',
#   'crimetypeid': '1',
#   'crimecategory': 'Property Crime',
#   'crimecategoryid': '1',
#   'location': '20XX LABIEUX RD',
#   'locationid': '39873',
#   'neighbourhood': 'Northfield',
#   'neighbourhoodid': '5',
#   'lat': '49.197667',
#   'long': '-123.987601'},
#  {'id': '4201201923231',
#   'file': '2019-23231',
#   'date': ['6/20/2019', '5:22:00', 'AM'],
#   'occurrencetype': 'Commercial Break and Enter',
#   'occurrencetypeid': '2120-01',
#   'crimetype': 'Break and Enter',
#   'crimetypeid': '1',
#   'crimecategory': 'Property Crime',
#   'crimecategoryid': '1',
#   'location': '20XX LABIEUX RD',
#   'locationid': '39873',
#   'neighbourhood': 'Northfield',
#   'neighbourhoodid': '5',
#   'lat': '49.197667',
#   'long': '-123.987601'},
#  {'id': '4201201913690',
#   'file': '2019-13690',
#   'date': ['4/18/2019', '3:49:00', 'AM'],
#   'occurrencetype': 'Commercial Break and Enter',
#   'occurrencetypeid': '2120-01',
#   'crimetype': 'Break and Enter',
#   'crimetypeid': '1',
#   'crimecategory': 'Property Crime',
#   'crimecategoryid': '1',
#   'location': '21XX BOWEN RD',
#   'locationid': '39881',
#   'neighbourhood': 'Northfield',
#   'neighbourhoodid': '5',
#   'lat': '49.189191',
#   'long': '-123.988675'},
#  {'id': '4201201913082',
#   'file': '2019-13082',
#   'date': ['4/14/2019', '8:21:00', 'AM'],
#   'occurrencetype': 'Commercial Break and Enter',
#   'occurrencetypeid': '2120-01',
#   'crimetype': 'Break and Enter',
#   'crimetypeid': '1',
#   'crimecategory': 'Property Crime',
#   'crimecategoryid': '1',
#   'location': '21XX BOWEN RD',
#   'locationid': '39882',
#   'neighbourhood': 'Northfield',
#   'neighbourhoodid': '5',
#   'lat': '49.190728',
#   'long': '-123.990448'},
#  {'id': '4201201926391',
#   'file': '2019-26391',
#   'date': ['7/10/2019', '3:55:00', 'AM'],
#   'occurrencetype': 'Commercial Break and Enter',
#   'occurrencetypeid': '2120-01',
#   'crimetype': 'Break and Enter',
#   'crimetypeid': '1',
#   'crimecategory': 'Property Crime',
#   'crimecategoryid': '1',
#   'location': '22XX BOWEN RD',
#   'locationid': '39901',
#   'neighbourhood': 'Northfield',
#   'neighbourhoodid': '5',
#   'lat': '49.194359',
#   'long': '-123.993105'},
#  {'id': '4201201923563',
#   'file': '2019-23563',
#   'date': ['6/21/2019', '7:30:00', 'PM'],
#   'occurrencetype': 'Commercial Break and Enter',
#   'occurrencetypeid': '2120-01',
#   'crimetype': 'Break and Enter',
#   'crimetypeid': '1',
#   'crimecategory': 'Property Crime',
#   'crimecategoryid': '1',
#   'location': '22XX BOWEN RD',
#   'locationid': '39901',
#   'neighbourhood': 'Northfield',
#   'neighbourhoodid': '5',
#   'lat': '49.194359',
#   'long': '-123.993105'},
#  {'id': '4201201915589',
#   'file': '2019-15589',
#   'date': ['5/1/2019', '8:29:00', 'AM'],
#   'occurrencetype': 'Commercial Break and Enter',
#   'occurrencetypeid': '2120-01',
#   'crimetype': 'Break and Enter',
#   'crimetypeid': '1',
#   'crimecategory': 'Property Crime',
#   'crimecategoryid': '1',
#   'location': '22XX BOWEN RD',
#   'locationid': '39901',
#   'neighbourhood': 'Northfield',
#   'neighbourhoodid': '5',
#   'lat': '49.194359',
#   'long': '-123.993105'},
#  {'id': '4201201931111',
#   'file': '2019-31111',
#   'date': ['8/8/2019', '7:15:00', 'AM'],
#   'occurrencetype': 'Commercial Break and Enter',
#   'occurrencetypeid': '2120-01',
#   'crimetype': 'Break and Enter',
#   'crimetypeid': '1',
#   'crimecategory': 'Property Crime',
#   'crimecategoryid': '1',
#   'location': '22XX DORMAN RD',
#   'locationid': '39902',
#   'neighbourhood': 'Northfield',
#   'neighbourhoodid': '5',
#   'lat': '49.193144',
#   'long': '-123.985568'},
#  {'id': '4201201926730',
#   'file': '2019-26730',
#   'date': ['7/12/2019', '9:03:00', 'AM'],
#   'occurrencetype': 'Commercial Break and Enter',
#   'occurrencetypeid': '2120-01',
#   'crimetype': 'Break and Enter',
#   'crimetypeid': '1',
#   'crimecategory': 'Property Crime',
#   'crimecategoryid': '1',
#   'location': '22XX DORMAN RD',
#   'locationid': '39902',
#   'neighbourhood': 'Northfield',
#   'neighbourhoodid': '5',
#   'lat': '49.193144',
#   'long': '-123.985568'},
#  {'id': '4201201923311',
#   'file': '2019-23311',
#   'date': ['6/20/2019', '2:34:00', 'PM'],
#   'occurrencetype': 'Commercial Break and Enter',
#   'occurrencetypeid': '2120-01',
#   'crimetype': 'Break and Enter',
#   'crimetypeid': '1',
#   'crimecategory': 'Property Crime',
#   'crimecategoryid': '1',
#   'location': '22XX MCGARRIGLE RD',
#   'locationid': '39908',
#   'neighbourhood': 'Northfield',
#   'neighbourhoodid': '5',
#   'lat': '49.195371',
#   'long': '-123.983382'},
#  {'id': '4201201912710',
#   'file': '2019-12710',
#   'date': ['4/11/2019', '9:45:00', 'AM'],
#   'occurrencetype': 'Commercial Break and Enter',
#   'occurrencetypeid': '2120-01',
#   'crimetype': 'Break and Enter',
#   'crimetypeid': '1',
#   'crimecategory': 'Property Crime',
#   'crimecategoryid': '1',
#   'location': '22XX PETERSEN PL',
#   'locationid': '39910',
#   'neighbourhood': 'Northfield',
#   'neighbourhoodid': '5',
#   'lat': '49.192395',
#   'long': '-123.974428'},
#  {'id': '4201201918002',
#   'file': '2019-18002',
#   'date': ['5/17/2019', '4:15:00', 'AM'],
#   'occurrencetype': 'Commercial Break and Enter',
#   'occurrencetypeid': '2120-01',
#   'crimetype': 'Break and Enter',
#   'crimetypeid': '1',
#   'crimecategory': 'Property Crime',
#   'crimecategoryid': '1',
#   'location': '25XX BOWEN RD',
#   'locationid': '39914',
#   'neighbourhood': 'Northfield',
#   'neighbourhoodid': '5',
#   'lat': '49.200855',
#   'long': '-123.999848'},
#  {'id': '4201201927187',
#   'file': '2019-27187',
#   'date': ['7/15/2019', '7:19:00', 'AM'],
#   'occurrencetype': 'Commercial Break and Enter',
#   'occurrencetypeid': '2120-01',
#   'crimetype': 'Break and Enter',
#   'crimetypeid': '1',
#   'crimecategory': 'Property Crime',
#   'crimecategoryid': '1',
#   'location': '25XX MCCULLOUGH RD',
#   'locationid': '39917',
#   'neighbourhood': 'Northfield',
#   'neighbourhoodid': '5',
#   'lat': '49.196917',
#   'long': '-123.982662'},
#  {'id': '4201201928139',
#   'file': '2019-28139',
#   'date': ['7/20/2019', '9:53:00', 'PM'],
#   'occurrencetype': 'Commercial Break and Enter',
#   'occurrencetypeid': '2120-01',
#   'crimetype': 'Break and Enter',
#   'crimetypeid': '1',
#   'crimecategory': 'Property Crime',
#   'crimecategoryid': '1',
#   'location': '4XX MADSEN RD',
#   'locationid': '39921',
#   'neighbourhood': 'Northfield',
#   'neighbourhoodid': '5',
#   'lat': '49.178818',
#   'long': '-123.982766'},
#  {'id': '4201201926567',
#   'file': '2019-26567',
#   'date': ['7/11/2019', '7:49:00', 'AM'],
#   'occurrencetype': 'Commercial Break and Enter',
#   'occurrencetypeid': '2120-01',
#   'crimetype': 'Break and Enter',
#   'crimetypeid': '1',
#   'crimecategory': 'Property Crime',
#   'crimecategoryid': '1',
#   'location': '4XX MADSEN RD',
#   'locationid': '39921',
#   'neighbourhood': 'Northfield',
#   'neighbourhoodid': '5',
#   'lat': '49.178818',
#   'long': '-123.982766'},
#  {'id': '4201201920607',
#   'file': '2019-20607',
#   'date': ['6/3/2019', '12:38:00', 'PM'],
#   'occurrencetype': 'Commercial Break and Enter',
#   'occurrencetypeid': '2120-01',
#   'crimetype': 'Break and Enter',
#   'crimetypeid': '1',
#   'crimecategory': 'Property Crime',
#   'crimecategoryid': '1',
#   'location': '4XX MADSEN RD',
#   'locationid': '39921',
#   'neighbourhood': 'Northfield',
#   'neighbourhoodid': '5',
#   'lat': '49.178818',
#   'long': '-123.982766'},
#  {'id': '4201201919477',
#   'file': '2019-19477',
#   'date': ['5/27/2019', '10:03:00', 'AM'],
#   'occurrencetype': 'Commercial Break and Enter',
#   'occurrencetypeid': '2120-01',
#   'crimetype': 'Break and Enter',
#   'crimetypeid': '1',
#   'crimecategory': 'Property Crime',
#   'crimecategoryid': '1',
#   'location': '4XX MADSEN RD',
#   'locationid': '39921',
#   'neighbourhood': 'Northfield',
#   'neighbourhoodid': '5',
#   'lat': '49.178818',
#   'long': '-123.982766'},
#  {'id': '4201201916358',
#   'file': '2019-16358',
#   'date': ['5/6/2019', '2:37:00', 'PM'],
#   'occurrencetype': 'Commercial Break and Enter',
#   'occurrencetypeid': '2120-01',
#   'crimetype': 'Break and Enter',
#   'crimetypeid': '1',
#   'crimecategory': 'Property Crime',
#   'crimecategoryid': '1',
#   'location': '4XX MADSEN RD',
#   'locationid': '39921',
#   'neighbourhood': 'Northfield',
#   'neighbourhoodid': '5',
#   'lat': '49.178818',
#   'long': '-123.982766'},
#  {'id': '4201201915897',
#   'file': '2019-15897',
#   'date': ['5/3/2019', '6:27:00', 'AM'],
#   'occurrencetype': 'Commercial Break and Enter',
#   'occurrencetypeid': '2120-01',
#   'crimetype': 'Break and Enter',
#   'crimetypeid': '1',
#   'crimecategory': 'Property Crime',
#   'crimecategoryid': '1',
#   'location': '1XX BOWLSBY ST',
#   'locationid': '39944',
#   'neighbourhood': 'South End',
#   'neighbourhoodid': '6',
#   'lat': '49.141165',
#   'long': '-123.929975'},
#  {'id': '4201201925581',
#   'file': '2019-25581',
#   'date': ['7/4/2019', '11:54:00', 'PM'],
#   'occurrencetype': 'Commercial Break and Enter',
#   'occurrencetypeid': '2120-01',
#   'crimetype': 'Break and Enter',
#   'crimetypeid': '1',
#   'crimecategory': 'Property Crime',
#   'crimecategoryid': '1',
#   'location': '1XX HALIBURTON ST',
#   'locationid': '39951',
#   'neighbourhood': 'South End',
#   'neighbourhoodid': '6',
#   'lat': '49.158921',
#   'long': '-123.932726'},
#  {'id': '4201201924358',
#   'file': '2019-24358',
#   'date': ['6/26/2019', '11:00:00', 'PM'],
#   'occurrencetype': 'Commercial Break and Enter',
#   'occurrencetypeid': '2120-01',
#   'crimetype': 'Break and Enter',
#   'crimetypeid': '1',
#   'crimecategory': 'Property Crime',
#   'crimecategoryid': '1',
#   'location': '1XX NICOL ST',
#   'locationid': '39953',
#   'neighbourhood': 'South End',
#   'neighbourhoodid': '6',
#   'lat': '49.158919',
#   'long': '-123.934133'},
#  {'id': '4201201928468',
#   'file': '2019-28468',
#   'date': ['7/23/2019', '3:47:00', 'AM'],
# ...
#   'crimetype': 'Theft',
#   'crimetypeid': '4',
#   'crimecategory': 'Property Crime',
#   'crimecategoryid': '1',
#   'location': '8XX ISLAND HWY S',
#   'locationid': '40000',
#   'neighbourhood': 'South End',
#   'neighbourhoodid': '6',
#   'lat': '49.146305',
#   'long': '-123.932418'},
#  {'id': '4201201933636',
#   'file': '2019-33636',
#   'date': ['8/23/2019', '6:00:00', 'PM'],
#   'occurrencetype': 'Theft Other Under $5000',
#   'occurrencetypeid': '2140-13',
#   'crimetype': 'Theft',
#   'crimetypeid': '4',
#   'crimecategory': 'Property Crime',
#   'crimecategoryid': '1',
#   'location': '8XX OLD VICTORIA RD',
#   'locationid': '40002',
#   'neighbourhood': 'South End',
#   'neighbourhoodid': '6',
#   'lat': '49.145499',
#   'long': '-123.936396'},
#  {'id': '4201201932466',
#   'file': '2019-32466',
#   'date': ['8/16/2019', '10:12:00', 'PM'],
#   'occurrencetype': 'Theft Other Under $5000',
#   'occurrencetypeid': '2140-13',
#   'crimetype': 'Theft',
#   'crimetypeid': '4',
#   'crimecategory': 'Property Crime',
#   'crimecategoryid': '1',
#   'location': '8XX OLD VICTORIA RD',
#   'locationid': '40002',
#   'neighbourhood': 'South End',
#   'neighbourhoodid': '6',
#   'lat': '49.145499',
#   'long': '-123.936396'},
#  {'id': '4201201931833',
#   'file': '2019-31833',
#   'date': ['8/13/2019', '12:36:00', 'AM'],
#   'occurrencetype': 'Theft Other Under $5000',
#   'occurrencetypeid': '2140-13',
#   'crimetype': 'Theft',
#   'crimetypeid': '4',
#   'crimecategory': 'Property Crime',
#   'crimecategoryid': '1',
#   'location': '8XX OLD VICTORIA RD',
#   'locationid': '40002',
#   'neighbourhood': 'South End',
#   'neighbourhoodid': '6',
#   'lat': '49.145499',
#   'long': '-123.936396'},
#  {'id': '4201201934314',
#   'file': '2019-34314',
#   'date': ['8/28/2019', '9:46:00', 'AM'],
#   'occurrencetype': 'Theft Other Under $5000',
#   'occurrencetypeid': '2140-13',
#   'crimetype': 'Theft',
#   'crimetypeid': '4',
#   'crimecategory': 'Property Crime',
#   'crimecategoryid': '1',
#   'location': '8XX VICTORIA RD',
#   'locationid': '40004',
#   'neighbourhood': 'South End',
#   'neighbourhoodid': '6',
#   'lat': '49.148469',
#   'long': '-123.93716'},
#  {'id': '4201201921261',
#   'file': '2019-21261',
#   'date': ['6/7/2019', '7:01:00', 'PM'],
#   'occurrencetype': 'Theft Other Under $5000',
#   'occurrencetypeid': '2140-13',
#   'crimetype': 'Theft',
#   'crimetypeid': '4',
#   'crimecategory': 'Property Crime',
#   'crimecategoryid': '1',
#   'location': '8XX VICTORIA RD',
#   'locationid': '40004',
#   'neighbourhood': 'South End',
#   'neighbourhoodid': '6',
#   'lat': '49.148469',
#   'long': '-123.93716'},
#  {'id': '4201201933204',
#   'file': '2019-33204',
#   'date': ['8/21/2019', '7:20:00', 'PM'],
#   'occurrencetype': 'Theft Other Under $5000',
#   'occurrencetypeid': '2140-13',
#   'crimetype': 'Theft',
#   'crimetypeid': '4',
#   'crimecategory': 'Property Crime',
#   'crimecategoryid': '1',
#   'location': '9XX HALIBURTON ST',
#   'locationid': '40006',
#   'neighbourhood': 'South End',
#   'neighbourhoodid': '6',
#   'lat': '49.142811',
#   'long': '-123.926407'},
#  {'id': '4201201915477',
#   'file': '2019-15477',
#   'date': ['4/30/2019', '12:17:00', 'PM'],
#   'occurrencetype': 'Theft Other Under $5000',
#   'occurrencetypeid': '2140-13',
#   'crimetype': 'Theft',
#   'crimetypeid': '4',
#   'crimecategory': 'Property Crime',
#   'crimecategoryid': '1',
#   'location': '9XX HALIBURTON ST',
#   'locationid': '40007',
#   'neighbourhood': 'South End',
#   'neighbourhoodid': '6',
#   'lat': '49.145203',
#   'long': '-123.930062'},
#  {'id': '4201201916558',
#   'file': '2019-16558',
#   'date': ['5/7/2019', '10:32:00', 'PM'],
#   'occurrencetype': 'Theft Other Under $5000',
#   'occurrencetypeid': '2140-13',
#   'crimetype': 'Theft',
#   'crimetypeid': '4',
#   'crimecategory': 'Property Crime',
#   'crimecategoryid': '1',
#   'location': 'NICOL ST / NEEDHAM ST',
#   'locationid': '40017',
#   'neighbourhood': 'South End',
#   'neighbourhoodid': '6',
#   'lat': '49.153361',
#   'long': '-123.933858'},
#  {'id': '4201201934655',
#   'file': '2019-34655',
#   'date': ['8/30/2019', '12:48:00', 'PM'],
#   'occurrencetype': 'Theft Other Under $5000',
#   'occurrencetypeid': '2140-13',
#   'crimetype': 'Theft',
#   'crimetypeid': '4',
#   'crimecategory': 'Property Crime',
#   'crimecategoryid': '1',
#   'location': 'NICOL ST / TERMINAL AVE',
#   'locationid': '40018',
#   'neighbourhood': 'South End',
#   'neighbourhoodid': '6',
#   'lat': '49.163041',
#   'long': '-123.934292'},
#  {'id': '4201201932526',
#   'file': '2019-32526',
#   'date': ['8/17/2019', '12:23:00', 'PM'],
#   'occurrencetype': 'Theft Other Under $5000',
#   'occurrencetypeid': '2140-13',
#   'crimetype': 'Theft',
#   'crimetypeid': '4',
#   'crimecategory': 'Property Crime',
#   'crimecategoryid': '1',
#   'location': 'WOODHOUSE ST / HALIBURTON ST',
#   'locationid': '40024',
#   'neighbourhood': 'South End',
#   'neighbourhoodid': '6',
#   'lat': '49.148132',
#   'long': '-123.932146'},
#  {'id': '4201201936256',
#   'file': '2019-36256',
#   'date': ['9/10/2019', '7:16:00', 'AM'],
#   'occurrencetype': 'Theft Other Under $5000',
#   'occurrencetypeid': '2140-13',
#   'crimetype': 'Theft',
#   'crimetypeid': '4',
#   'crimecategory': 'Property Crime',
#   'crimecategoryid': '1',
#   'location': 'X GILLESPIE ST',
#   'locationid': '40025',
#   'neighbourhood': 'South End',
#   'neighbourhoodid': '6',
#   'lat': '49.152048',
#   'long': '-123.931342'},
#  {'id': '4201201928683',
#   'file': '2019-28683',
#   'date': ['7/24/2019', '4:00:00', 'AM'],
#   'occurrencetype': 'Theft Other Under $5000',
#   'occurrencetypeid': '2140-13',
#   'crimetype': 'Theft',
#   'crimetypeid': '4',
#   'crimecategory': 'Property Crime',
#   'crimecategoryid': '1',
#   'location': 'XX HALIBURTON ST',
#   'locationid': '40033',
#   'neighbourhood': 'South End',
#   'neighbourhoodid': '6',
#   'lat': '49.160911',
#   'long': '-123.932827'},
#  {'id': '4201201916968',
#   'file': '2019-16968',
#   'date': ['5/10/2019', '2:17:00', 'PM'],
#   'occurrencetype': 'Theft Other Under $5000',
#   'occurrencetypeid': '2140-13',
#   'crimetype': 'Theft',
#   'crimetypeid': '4',
#   'crimecategory': 'Property Crime',
#   'crimecategoryid': '1',
#   'location': 'XX NICOL ST',
#   'locationid': '40037',
#   'neighbourhood': 'South End',
#   'neighbourhoodid': '6',
#   'lat': '49.160883',
#   'long': '-123.934231'},
#  {'id': '4201201937318',
#   'file': '2019-37318',
#   'date': ['9/16/2019', '5:59:00', 'PM'],
#   'occurrencetype': 'Theft Other Under $5000',
#   'occurrencetypeid': '2140-13',
#   'crimetype': 'Theft',
#   'crimetypeid': '4',
#   'crimecategory': 'Property Crime',
#   'crimecategoryid': '1',
#   'location': '49XX NEY DR',
#   'locationid': '40048',
#   'neighbourhood': 'North Slope',
#   'neighbourhoodid': '7',
#   'lat': '49.234135',
#   'long': '-123.982854'},
#  {'id': '4201201913671',
#   'file': '2019-13671',
#   'date': ['4/18/2019', '11:45:00', 'AM'],
#   'occurrencetype': 'Theft Other Under $5000',
#   'occurrencetypeid': '2140-13',
#   'crimetype': 'Theft',
#   'crimetypeid': '4',
#   'crimecategory': 'Property Crime',
#   'crimecategoryid': '1',
#   'location': '57XX BRADBURY RD',
#   'locationid': '40060',
#   'neighbourhood': 'North Slope',
#   'neighbourhoodid': '7',
#   'lat': '49.23266',
#   'long': '-124.019401'},
#  {'id': '4201201924263',
#   'file': '2019-24263',
#   'date': ['6/26/2019', '1:27:00', 'PM'],
#   'occurrencetype': 'Theft Other Under $5000',
#   'occurrencetypeid': '2140-13',
#   'crimetype': 'Theft',
#   'crimetypeid': '4',
#   'crimecategory': 'Property Crime',
#   'crimecategoryid': '1',
#   'location': 'XX RILEY PL',
#   'locationid': '40069',
#   'neighbourhood': 'North Slope',
#   'neighbourhoodid': '7',
#   'lat': '49.230021',
#   'long': '-123.985001'},
#  {'id': '4201201925728',
#   'file': '2019-25728',
#   'date': ['7/5/2019', '1:00:00', 'PM'],
#   'occurrencetype': 'Theft Other Under $5000',
#   'occurrencetypeid': '2140-13',
#   'crimetype': 'Theft',
#   'crimetypeid': '4',
#   'crimecategory': 'Property Crime',
#   'crimecategoryid': '1',
#   'location': '10XX HALIBURTON ST',
#   'locationid': '40072',
#   'neighbourhood': 'Chase River',
#   'neighbourhoodid': '8',
#   'lat': '49.139739',
#   'long': '-123.922177'},
#  {'id': '4201201912636',
#   'file': '2019-12636',
#   'date': ['4/10/2019', '5:11:00', 'PM'],
#   'occurrencetype': 'Theft Other Under $5000',
#   'occurrencetypeid': '2140-13',
#   'crimetype': 'Theft',
#   'crimetypeid': '4',
#   'crimecategory': 'Property Crime',
#   'crimecategoryid': '1',
#   'location': '10XX ISLAND HWY S',
#   'locationid': '40073',
#   'neighbourhood': 'Chase River',
#   'neighbourhoodid': '8',
#   'lat': '49.138959',
#   'long': '-123.925956'},
#  {'id': '4201201918636',
#   'file': '2019-18636',
#   'date': ['5/21/2019', '8:59:00', 'PM'],
#   'occurrencetype': 'Theft Other Under $5000',
#   'occurrencetypeid': '2140-13',
#   'crimetype': 'Theft',
#   'crimetypeid': '4',
#   'crimecategory': 'Property Crime',
#   'crimecategoryid': '1',
#   'location': '11XX OLD VICTORIA RD',
#   'locationid': '40079',
#   'neighbourhood': 'Chase River',
#   'neighbourhoodid': '8',
#   'lat': '49.13444',
#   'long': '-123.922271'},
#  {'id': '4201201931232',
#   'file': '2019-31232',
#   'date': ['8/8/2019', '10:08:00', 'PM'],
#   'occurrencetype': 'Theft Other Under $5000',
#   'occurrencetypeid': '2140-13',
#   'crimetype': 'Theft',
#   'crimetypeid': '4',
#   'crimecategory': 'Property Crime',
#   'crimecategoryid': '1',
#   'location': '12XX ISLAND HWY S',
#   'locationid': '40080',
#   'neighbourhood': 'Chase River',
#   'neighbourhoodid': '8',
#   'lat': '49.129359',
#   'long': '-123.9206'},
#  {'id': '4201201928115',
#   'file': '2019-28115',
#   'date': ['7/20/2019', '5:54:00', 'PM'],
#   'occurrencetype': 'Theft Other Under $5000',
#   'occurrencetypeid': '2140-13',
#   'crimetype': 'Theft',
#   'crimetypeid': '4',
#   'crimecategory': 'Property Crime',
#   'crimecategoryid': '1',
#   'location': '12XX ISLAND HWY S',
#   'locationid': '40080',
#   'neighbourhood': 'Chase River',
#   'neighbourhoodid': '8',
#   'lat': '49.129359',
#   'long': '-123.9206'},
#  {'id': '4201201917657',
#   'file': '2019-17657',
#   'date': ['5/15/2019', '2:07:00', 'AM'],
#   'occurrencetype': 'Theft Other Under $5000',
#   'occurrencetypeid': '2140-13',
#   'crimetype': 'Theft',
#   'crimetypeid': '4',
#   'crimecategory': 'Property Crime',
#   'crimecategoryid': '1',
#   'location': '12XX ISLAND HWY S',
#   'locationid': '40080',
#   'neighbourhood': 'Chase River',
#   'neighbourhoodid': '8',
#   'lat': '49.129359',
#   'long': '-123.9206'},
#  {'id': '4201201913255',
#   'file': '2019-13255',
#   'date': ['4/15/2019', '4:06:00', 'PM'],
#   'occurrencetype': 'Theft Other Under $5000',
#   'occurrencetypeid': '2140-13',
#   'crimetype': 'Theft',
#   'crimetypeid': '4',
#   'crimecategory': 'Property Crime',
#   'crimecategoryid': '1',
#   'location': '12XX ISLAND HWY S',
#   'locationid': '40080',
#   'neighbourhood': 'Chase River',
#   'neighbourhoodid': '8',
#   'lat': '49.129359',
#   'long': '-123.9206'},
#  {'id': '4201201932189',
#   'file': '2019-32189',
#   'date': ['8/15/2019', '8:32:00', 'AM'],
#   'occurrencetype': 'Theft Other Under $5000',
#   'occurrencetypeid': '2140-13',
#   'crimetype': 'Theft',
#   'crimetypeid': '4',
#   'crimecategory': 'Property Crime',
#   'crimecategoryid': '1',
#   'location': '13XX FIELDING RD',
#   'locationid': '40083',
#   'neighbourhood': 'Chase River',
#   'neighbourhoodid': '8',
#   'lat': '49.126944',
#   'long': '-123.910019'},
#  {'id': '4201201915289',
#   'file': '2019-15289',
#   'date': ['4/28/2019', '10:00:00', 'PM'],
#   'occurrencetype': 'Theft Other Under $5000',
#   'occurrencetypeid': '2140-13',
#   'crimetype': 'Theft',
#   'crimetypeid': '4',
#   'crimecategory': 'Property Crime',
#   'crimecategoryid': '1',
#   'location': '13XX FIELDING RD',
#   'locationid': '40083',
#   'neighbourhood': 'Chase River',
#   'neighbourhoodid': '8',
#   'lat': '49.126944',
#   'long': '-123.910019'},
#  {'id': '4201201914445',
#   'file': '2019-14445',
#   'date': ['4/24/2019', '12:56:00', 'AM'],
#   'occurrencetype': 'Theft Other Under $5000',
#   'occurrencetypeid': '2140-13',
#   'crimetype': 'Theft',
#   'crimetypeid': '4',
#   'crimecategory': 'Property Crime',
#   'crimecategoryid': '1',
#   'location': '17XX HARAMBE WAY',
#   'locationid': '40094',
#   'neighbourhood': 'Chase River',
#   'neighbourhoodid': '8',
#   'lat': '49.116021',
#   'long': '-123.931436'},
#  {'id': '4201201933977',
#   'file': '2019-33977',
#   'date': ['8/26/2019', '11:13:00', 'AM'],
#   'occurrencetype': 'Theft Other Under $5000',
#   'occurrencetypeid': '2140-13',
#   'crimetype': 'Theft',
#   'crimetypeid': '4',
#   'crimecategory': 'Property Crime',
#   'crimecategoryid': '1',
#   'location': '21XX LAKESIDE DR',
#   'locationid': '40104',
#   'neighbourhood': 'Chase River',
#   'neighbourhoodid': '8',
#   'lat': '49.098942',
#   'long': '-123.930014'},
#  {'id': '4201201925171',
#   'file': '2019-25171',
#   'date': ['6/29/2019', '2:00:00', 'PM'],
#   'occurrencetype': 'Theft Other Under $5000',
#   'occurrencetypeid': '2140-13',
#   'crimetype': 'Theft',
#   'crimetypeid': '4',
#   'crimecategory': 'Property Crime',
#   'crimecategoryid': '1',
#   'location': '9XX CEDAR RD',
#   'locationid': '40109',
#   'neighbourhood': 'Chase River',
#   'neighbourhoodid': '8',
#   'lat': '49.123356',
#   'long': '-123.912111'},
#  {'id': '4201201916125',
#   'file': '2019-16125',
#   'date': ['5/4/2019', '3:32:00', 'PM'],
#   'occurrencetype': 'Theft Other Under $5000',
#   'occurrencetypeid': '2140-13',
#   'crimetype': 'Theft',
#   'crimetypeid': '4',
#   'crimecategory': 'Property Crime',
#   'crimecategoryid': '1',
#   'location': 'CEDAR RD / ISLAND HWY S',
#   'locationid': '40110',
#   'neighbourhood': 'Chase River',
#   'neighbourhoodid': '8',
#   'lat': '49.124686',
#   'long': '-123.916484'},
#  {'id': '4201201917870',
#   'file': '2019-17870',
#   'date': ['5/16/2019', '9:24:00', 'AM'],
#   'occurrencetype': 'Theft Other Under $5000',
#   'occurrencetypeid': '2140-13',
#   'crimetype': 'Theft',
#   'crimetypeid': '4',
#   'crimecategory': 'Property Crime',
#   'crimecategoryid': '1',
#   'location': 'CRANBERRY AVE / EXTENSION RD',
#   'locationid': '40112',
#   'neighbourhood': 'Chase River',
#   'neighbourhoodid': '8',
#   'lat': '49.124096',
#   'long': '-123.91996'},
#  {'id': '4201201926412',
#   'file': '2019-26412',
#   'date': ['7/9/2019', '10:00:00', 'PM'],
#   'occurrencetype': 'Theft Other Under $5000',
#   'occurrencetypeid': '2140-13',
#   'crimetype': 'Theft',
#   'crimetypeid': '4',
#   'crimecategory': 'Property Crime',
#   'crimecategoryid': '1',
#   'location': 'DUKE POINT HWY / DUKE POINT HWY ONRP',
#   'locationid': '40113',
#   'neighbourhood': 'Chase River',
#   'neighbourhoodid': '8',
#   'lat': '49.112394',
#   'long': '-123.895229'},
#  {'id': '4201201926057',
#   'file': '2019-26057',
#   'date': ['7/8/2019', '8:53:00', 'AM'],
#   'occurrencetype': 'Theft Other Under $5000',
#   'occurrencetypeid': '2140-13',
#   'crimetype': 'Theft',
#   'crimetypeid': '4',
#   'crimecategory': 'Property Crime',
#   'crimecategoryid': '1',
#   'location': 'DUKE POINT HWY OFRP / DUKE POINT HWY',
#   'locationid': '40114',
#   'neighbourhood': 'Chase River',
#   'neighbourhoodid': '8',
#   'lat': '49.110505',
#   'long': '-123.904594'},
#  {'id': '4201201929421',
#   'file': '2019-29421',
#   'date': ['7/28/2019', '1:31:00', 'PM'],
#   'occurrencetype': 'Theft Other Under $5000',
#   'occurrencetypeid': '2140-13',
#   'crimetype': 'Theft',
#   'crimetypeid': '4',
#   'crimecategory': 'Property Crime',
#   'crimecategoryid': '1',
#   'location': 'ISLAND HWY S / CEDAR RD',
#   'locationid': '40118',
#   'neighbourhood': 'Chase River',
#   'neighbourhoodid': '8',
#   'lat': '49.124595',
#   'long': '-123.916406'},
#  {'id': '4201201918881',
#   'file': '2019-18881',
#   'date': ['5/17/2019', '10:00:00', 'PM'],
#   'occurrencetype': 'Theft Other Under $5000',
#   'occurrencetypeid': '2140-13',
#   'crimetype': 'Theft',
#   'crimetypeid': '4',
#   'crimecategory': 'Property Crime',
#   'crimecategoryid': '1',
#   'location': 'ISLAND HWY S / CEDAR RD',
#   'locationid': '40118',
#   'neighbourhood': 'Chase River',
#   'neighbourhoodid': '8',
#   'lat': '49.124595',
#   'long': '-123.916406'},
#  {'id': '4201201920025',
#   'file': '2019-20025',
#   'date': ['5/30/2019', '2:03:00', 'PM'],
#   'occurrencetype': 'Theft Other Under $5000',
#   'occurrencetypeid': '2140-13',
#   'crimetype': 'Theft',
#   'crimetypeid': '4',
#   'crimecategory': 'Property Crime',
#   'crimecategoryid': '1',
#   'location': 'XX MAKI RD',
#   'locationid': '40126',
#   'neighbourhood': 'Chase River',
#   'neighbourhoodid': '8',
#   'lat': '49.130929',
#   'long': '-123.917326'},
#  ...]

# %%
LAT = [float(crime['lat']) for crime in dat]
LONG = [float(crime['long']) for crime in dat] 
avg_lat = sum(LAT)/len(LAT)
avg_long = sum(LONG)/len(LONG)

# %%
plt.figure(figsize=(12,12))
plt.subplot(211)
plt.plot(LONG,LAT,'ro',markersize=2,alpha=0.4)
plt.plot(avg_long,avg_lat,'o',color='black',label='avg location of crime')
plt.legend()
# plt.ylim(49.12,49.19)
# plt.xlim(-123,975,-123,925)
plt.subplot(212)
plt.plot(LONG,LAT,'ro',markersize=2,alpha=0.3)
plt.plot(avg_long,avg_lat,'o',color='black',label='avg location of crime')
plt.ylim(49.12,49.19)
plt.legend()

# %%
neighbourhoods = set()
for crime in dat:
    neighbourhoods.add(crime['neighbourhood'])

# %%
LAT = [(float(crime['lat']), crime['neighbourhood']) for crime in dat]
LONG = [(float(crime['long']), crime['neighbourhood']) for crime in dat]

# %%
plt.close()
plt.figure(figsize=(15,10))
nDat = dict()
for n in neighbourhoods:
#     print(n)
    LAT_n = [float(crime['lat']) for crime in dat if crime['neighbourhood']==n]
    LONG_n = [float(crime['long']) for crime in dat if crime['neighbourhood']==n]
    nDat[n] = []
    for crime in dat:
        if crime['neighbourhood']==n:
            nDat[n].append(crime)
#     for j,ID in enumerate(ids):
                
#         if ID=='reportedtime':
#             Date = row[j].split(' ')
#             di['date'] = Date
#             continue
#         if ID == 'neighbourhood':
#             continue
        
#         di[n] = row[j]
#     nDat[n].append(row)
    print("%d crimes in "%len(LAT_n)+n)
#     print(LONGS,LATS,n)
    plt.plot(LONG_n,LAT_n,'o',markersize=3,alpha=0.4,label=n)
plt.legend()
# Out:
# 87 crimes in Westwood
# 309 crimes in Harewood
# 392 crimes in Northfield
# 247 crimes in Dover
# 196 crimes in Pleasant Valley
# 33 crimes in North Slope
# 39 crimes in Hammond Bay
# 1 crimes in Unknown
# 286 crimes in South End
# 29 crimes in Duke Pt
# 174 crimes in Departure Bay
# 83 crimes in Linley Valley
# 298 crimes in Newcastle/brechin
# 283 crimes in University District
# 101 crimes in Chase River
# 196 crimes in Townsite
# 299 crimes in Diver Lake
# 1050 crimes in Downtown
# 319 crimes in Rutherford

# %%
nDat
# Out:
# {'Westwood': [{'id': '4201201930641',
#    'file': '2019-30641',
#    'date': ['8/5/2019', '9:32:00', 'AM'],
#    'occurrencetype': 'Commercial Break and Enter',
#    'occurrencetypeid': '2120-01',
#    'crimetype': 'Break and Enter',
#    'crimetypeid': '1',
#    'crimecategory': 'Property Crime',
#    'crimecategoryid': '1',
#    'location': '20XX EAST WELLINGTON RD',
#    'locationid': '40982',
#    'neighbourhood': 'Westwood',
#    'neighbourhoodid': '18',
#    'lat': '49.180263',
#    'long': '-123.990227'},
#   {'id': '4201201936141',
#    'file': '2019-36141',
#    'date': ['9/9/2019', '10:25:00', 'AM'],
#    'occurrencetype': 'Commercial Break and Enter',
#    'occurrencetypeid': '2120-01',
#    'crimetype': 'Break and Enter',
#    'crimetypeid': '1',
#    'crimecategory': 'Property Crime',
#    'crimecategoryid': '1',
#    'location': '9XX FIFTH ST',
#    'locationid': '41010',
#    'neighbourhood': 'Westwood',
#    'neighbourhoodid': '18',
#    'lat': '49.155369',
#    'long': '-123.967743'},
#   {'id': '4201201919103',
#    'file': '2019-19103',
#    'date': ['5/17/2019', '1:37:00', 'PM'],
#    'occurrencetype': 'Commercial Break and Enter',
#    'occurrencetypeid': '2120-01',
#    'crimetype': 'Break and Enter',
#    'crimetypeid': '1',
#    'crimecategory': 'Property Crime',
#    'crimecategoryid': '1',
#    'location': '9XX FIFTH ST',
#    'locationid': '41010',
#    'neighbourhood': 'Westwood',
#    'neighbourhoodid': '18',
#    'lat': '49.155369',
#    'long': '-123.967743'},
#   {'id': '4201201918768',
#    'file': '2019-18768',
#    'date': ['5/20/2019', '4:36:00', 'PM'],
#    'occurrencetype': 'Residential Break and Enter',
#    'occurrencetypeid': '2120-02',
#    'crimetype': 'Break and Enter',
#    'crimetypeid': '1',
#    'crimecategory': 'Property Crime',
#    'crimecategoryid': '1',
#    'location': '1XX CHELAN PL',
#    'locationid': '40975',
#    'neighbourhood': 'Westwood',
#    'neighbourhoodid': '18',
#    'lat': '49.172568',
#    'long': '-123.991267'},
#   {'id': '4201201937444',
#    'file': '2019-37444',
#    'date': ['9/16/2019', '10:00:00', 'PM'],
#    'occurrencetype': 'Residential Break and Enter',
#    'occurrencetypeid': '2120-02',
#    'crimetype': 'Break and Enter',
#    'crimetypeid': '1',
#    'crimecategory': 'Property Crime',
#    'crimecategoryid': '1',
#    'location': '3XX WESTWOOD RD',
#    'locationid': '41007',
#    'neighbourhood': 'Westwood',
#    'neighbourhoodid': '18',
#    'lat': '49.164091',
#    'long': '-123.996686'},
#   {'id': '4201201938965',
#    'file': '2019-38965',
#    'date': ['9/27/2019', '7:52:00', 'AM'],
#    'occurrencetype': 'Other Break and Enter',
#    'occurrencetypeid': '2120-03',
#    'crimetype': 'Break and Enter',
#    'crimetypeid': '1',
#    'crimecategory': 'Property Crime',
#    'crimecategoryid': '1',
#    'location': '20XX EAST WELLINGTON RD',
#    'locationid': '40983',
#    'neighbourhood': 'Westwood',
#    'neighbourhoodid': '18',
#    'lat': '49.180608',
#    'long': '-123.991759'},
#   {'id': '4201201925391',
#    'file': '2019-25391',
#    'date': ['7/3/2019', '7:40:00', 'PM'],
#    'occurrencetype': 'Other Break and Enter',
#    'occurrencetypeid': '2120-03',
#    'crimetype': 'Break and Enter',
#    'crimetypeid': '1',
#    'crimecategory': 'Property Crime',
#    'crimecategoryid': '1',
#    'location': '20XX SKAHA DR',
#    'locationid': '40984',
#    'neighbourhood': 'Westwood',
#    'neighbourhoodid': '18',
#    'lat': '49.173684',
#    'long': '-123.988069'},
#   {'id': '4201201913194',
#    'file': '2019-13194',
#    'date': ['4/15/2019', '9:08:00', 'AM'],
#    'occurrencetype': 'Other Break and Enter',
#    'occurrencetypeid': '2120-03',
#    'crimetype': 'Break and Enter',
#    'crimetypeid': '1',
#    'crimecategory': 'Property Crime',
#    'crimecategoryid': '1',
#    'location': '9XX FIFTH ST',
#    'locationid': '41010',
#    'neighbourhood': 'Westwood',
#    'neighbourhoodid': '18',
#    'lat': '49.155369',
#    'long': '-123.967743'},
#   {'id': '4201201916661',
#    'file': '2019-16661',
#    'date': ['5/8/2019', '3:40:00', 'PM'],
#    'occurrencetype': 'Take Auto Without Consent Over $5000',
#    'occurrencetypeid': '2135-05',
#    'crimetype': 'Theft of Motor Vehicle',
#    'crimetypeid': '6',
#    'crimecategory': 'Property Crime',
#    'crimecategoryid': '1',
#    'location': '1XX CALDER RD',
#    'locationid': '40973',
#    'neighbourhood': 'Westwood',
#    'neighbourhoodid': '18',
#    'lat': '49.168507',
#    'long': '-123.986017'},
#   {'id': '4201201919551',
#    'file': '2019-19551',
#    'date': ['5/27/2019', '6:56:00', 'PM'],
#    'occurrencetype': 'Theft of Truck Under $5000',
#    'occurrencetypeid': '2135-07',
#    'crimetype': 'Theft of Motor Vehicle',
#    'crimetypeid': '6',
#    'crimecategory': 'Property Crime',
#    'crimecategoryid': '1',
#    'location': 'JINGLE POT RD / HARWELL RD',
#    'locationid': '41013',
#    'neighbourhood': 'Westwood',
#    'neighbourhoodid': '18',
#    'lat': '49.169307',
#    'long': '-123.988433'},
#   {'id': '4201201932975',
#    'file': '2019-32975',
#    'date': ['8/20/2019', '8:44:00', 'AM'],
#    'occurrencetype': 'Theft Bicycle Under $5000',
#    'occurrencetypeid': '2140-10',
#    'crimetype': 'Theft',
#    'crimetypeid': '4',
#    'crimecategory': 'Property Crime',
#    'crimecategoryid': '1',
#    'location': '1XX KING RD',
#    'locationid': '40977',
#    'neighbourhood': 'Westwood',
#    'neighbourhoodid': '18',
#    'lat': '49.167807',
#    'long': '-123.98274'},
#   {'id': '4201201933136',
#    'file': '2019-33136',
#    'date': ['8/20/2019', '5:00:00', 'AM'],
#    'occurrencetype': 'Theft Bicycle Under $5000',
#    'occurrencetypeid': '2140-10',
#    'crimetype': 'Theft',
#    'crimetypeid': '4',
#    'crimecategory': 'Property Crime',
#    'crimecategoryid': '1',
#    'location': '1XX KING RD',
#    'locationid': '40977',
#    'neighbourhood': 'Westwood',
#    'neighbourhoodid': '18',
#    'lat': '49.167807',
#    'long': '-123.98274'},
#   {'id': '4201201932266',
#    'file': '2019-32266',
#    'date': ['8/14/2019', '10:00:00', 'PM'],
#    'occurrencetype': 'Theft Bicycle Under $5000',
#    'occurrencetypeid': '2140-10',
#    'crimetype': 'Theft',
#    'crimetypeid': '4',
#    'crimecategory': 'Property Crime',
#    'crimecategoryid': '1',
#    'location': '21XX EAST WELLINGTON RD',
#    'locationid': '40985',
#    'neighbourhood': 'Westwood',
#    'neighbourhoodid': '18',
#    'lat': '49.181413',
#    'long': '-123.994643'},
#   {'id': '4201201922338',
#    'file': '2019-22338',
#    'date': ['6/14/2019', '4:05:00', 'PM'],
#    'occurrencetype': 'Theft Bicycle Under $5000',
#    'occurrencetypeid': '2140-10',
#    'crimetype': 'Theft',
#    'crimetypeid': '4',
#    'crimecategory': 'Property Crime',
#    'crimecategoryid': '1',
#    'location': '9XX FIFTH ST',
#    'locationid': '41010',
#    'neighbourhood': 'Westwood',
#    'neighbourhoodid': '18',
#    'lat': '49.155369',
#    'long': '-123.967743'},
#   {'id': '4201201919888',
#    'file': '2019-19888',
#    'date': ['5/29/2019', '5:56:00', 'PM'],
#    'occurrencetype': 'Theft Bicycle Under $5000',
#    'occurrencetypeid': '2140-10',
#    'crimetype': 'Theft',
#    'crimetypeid': '4',
#    'crimecategory': 'Property Crime',
#    'crimecategoryid': '1',
#    'location': '9XX FIFTH ST',
#    'locationid': '41010',
#    'neighbourhood': 'Westwood',
#    'neighbourhoodid': '18',
#    'lat': '49.155369',
#    'long': '-123.967743'},
#   {'id': '4201201914795',
#    'file': '2019-14795',
#    'date': ['4/26/2019', '7:24:00', 'AM'],
#    'occurrencetype': 'Theft Other Under $5000',
#    'occurrencetypeid': '2140-13',
#    'crimetype': 'Theft',
#    'crimetypeid': '4',
#    'crimecategory': 'Property Crime',
#    'crimecategoryid': '1',
#    'location': '13XX COLLEGE DR',
#    'locationid': '40969',
#    'neighbourhood': 'Westwood',
#    'neighbourhoodid': '18',
#    'lat': '49.162678',
#    'long': '-123.985769'},
#   {'id': '4201201931751',
#    'file': '2019-31751',
#    'date': ['8/12/2019', '12:49:00', 'PM'],
#    'occurrencetype': 'Theft Other Under $5000',
#    'occurrencetypeid': '2140-13',
#    'crimetype': 'Theft',
#    'crimetypeid': '4',
#    'crimecategory': 'Property Crime',
#    'crimecategoryid': '1',
#    'location': '19XX LEO TERR',
#    'locationid': '40972',
#    'neighbourhood': 'Westwood',
#    'neighbourhoodid': '18',
#    'lat': '49.171821',
#    'long': '-123.986309'},
#   {'id': '4201201939010',
#    'file': '2019-39010',
#    'date': ['9/27/2019', '2:20:00', 'AM'],
#    'occurrencetype': 'Theft Other Under $5000',
#    'occurrencetypeid': '2140-13',
#    'crimetype': 'Theft',
#    'crimetypeid': '4',
#    'crimecategory': 'Property Crime',
#    'crimecategoryid': '1',
#    'location': '1XX WESTWOOD RD',
#    'locationid': '40978',
#    'neighbourhood': 'Westwood',
#    'neighbourhoodid': '18',
#    'lat': '49.175434',
#    'long': '-123.98607'},
#   {'id': '4201201936001',
#    'file': '2019-36001',
#    'date': ['9/8/2019', '8:57:00', 'AM'],
#    'occurrencetype': 'Theft Other Under $5000',
#    'occurrencetypeid': '2140-13',
#    'crimetype': 'Theft',
#    'crimetypeid': '4',
#    'crimecategory': 'Property Crime',
#    'crimecategoryid': '1',
#    'location': '20XX CATHERS DR',
#    'locationid': '40980',
#    'neighbourhood': 'Westwood',
#    'neighbourhoodid': '18',
#    'lat': '49.173355',
#    'long': '-123.98726'},
#   {'id': '4201201937522',
#    'file': '2019-37522',
#    'date': ['9/18/2019', '12:27:00', 'AM'],
#    'occurrencetype': 'Theft Other Under $5000',
#    'occurrencetypeid': '2140-13',
#    'crimetype': 'Theft',
#    'crimetypeid': '4',
#    'crimecategory': 'Property Crime',
#    'crimecategoryid': '1',
#    'location': '22XX JINGLE POT RD',
#    'locationid': '40994',
#    'neighbourhood': 'Westwood',
#    'neighbourhoodid': '18',
#    'lat': '49.169152',
#    'long': '-123.987229'},
#   {'id': '4201201940326',
#    'file': '2019-40326',
#    'date': ['10/5/2019', '11:00:00', 'PM'],
#    'occurrencetype': 'Theft Other Under $5000',
#    'occurrencetypeid': '2140-13',
#    'crimetype': 'Theft',
#    'crimetypeid': '4',
#    'crimecategory': 'Property Crime',
#    'crimecategoryid': '1',
#    'location': '23XX ARBOT RD',
#    'locationid': '40995',
#    'neighbourhood': 'Westwood',
#    'neighbourhoodid': '18',
#    'lat': '49.166684',
#    'long': '-124.000721'},
#   {'id': '4201201939715',
#    'file': '2019-39715',
#    'date': ['10/2/2019', '5:08:00', 'AM'],
#    'occurrencetype': 'Theft Other Under $5000',
#    'occurrencetypeid': '2140-13',
#    'crimetype': 'Theft',
#    'crimetypeid': '4',
#    'crimecategory': 'Property Crime',
#    'crimecategoryid': '1',
#    'location': '23XX ARBOT RD',
#    'locationid': '40995',
#    'neighbourhood': 'Westwood',
#    'neighbourhoodid': '18',
#    'lat': '49.166684',
#    'long': '-124.000721'},
#   {'id': '4201201920466',
#    'file': '2019-20466',
#    'date': ['6/2/2019', '8:32:00', 'AM'],
#    'occurrencetype': 'Theft Other Under $5000',
#    'occurrencetypeid': '2140-13',
#    'crimetype': 'Theft',
#    'crimetypeid': '4',
#    'crimecategory': 'Property Crime',
#    'crimecategoryid': '1',
#    'location': '2XX WESTWOOD RD',
#    'locationid': '41003',
#    'neighbourhood': 'Westwood',
#    'neighbourhoodid': '18',
#    'lat': '49.167231',
#    'long': '-123.992919'},
#   {'id': '4201201935259',
#    'file': '2019-35259',
#    'date': ['9/3/2019', '12:29:00', 'PM'],
#    'occurrencetype': 'Theft Other Under $5000',
#    'occurrencetypeid': '2140-13',
#    'crimetype': 'Theft',
#    'crimetypeid': '4',
#    'crimecategory': 'Property Crime',
#    'crimecategoryid': '1',
#    'location': '9XX FIFTH ST',
#    'locationid': '41010',
#    'neighbourhood': 'Westwood',
#    'neighbourhoodid': '18',
#    'lat': '49.155369',
#    'long': '-123.967743'},
#   {'id': '4201201918520',
#    'file': '2019-18520',
#    'date': ['5/21/2019', '9:46:00', 'AM'],
#    'occurrencetype': 'Theft Other Under $5000',
#    'occurrencetypeid': '2140-13',
#    'crimetype': 'Theft',
#    'crimetypeid': '4',
#    'crimecategory': 'Property Crime',
#    'crimecategoryid': '1',
#    'location': '9XX FIFTH ST',
#    'locationid': '41010',
#    'neighbourhood': 'Westwood',
#    'neighbourhoodid': '18',
#    'lat': '49.155369',
#    'long': '-123.967743'},
#   {'id': '4201201915484',
#    'file': '2019-15484',
#    'date': ['4/30/2019', '12:31:00', 'PM'],
#    'occurrencetype': 'Theft Other Under $5000',
#    'occurrencetypeid': '2140-13',
#    'crimetype': 'Theft',
#    'crimetypeid': '4',
#    'crimecategory': 'Property Crime',
#    'crimecategoryid': '1',
#    'location': '9XX FIFTH ST',
#    'locationid': '41010',
#    'neighbourhood': 'Westwood',
#    'neighbourhoodid': '18',
#    'lat': '49.155369',
#    'long': '-123.967743'},
#   {'id': '4201201915483',
#    'file': '2019-15483',
#    'date': ['4/30/2019', '12:29:00', 'PM'],
#    'occurrencetype': 'Theft Other Under $5000',
#    'occurrencetypeid': '2140-13',
#    'crimetype': 'Theft',
#    'crimetypeid': '4',
#    'crimecategory': 'Property Crime',
#    'crimecategoryid': '1',
#    'location': '9XX FIFTH ST',
#    'locationid': '41010',
#    'neighbourhood': 'Westwood',
#    'neighbourhoodid': '18',
#    'lat': '49.155369',
#    'long': '-123.967743'},
#   {'id': '4201201912612',
#    'file': '2019-12612',
#    'date': ['4/10/2019', '3:12:00', 'PM'],
#    'occurrencetype': 'Theft Other Under $5000',
#    'occurrencetypeid': '2140-13',
#    'crimetype': 'Theft',
#    'crimetypeid': '4',
#    'crimecategory': 'Property Crime',
#    'crimecategoryid': '1',
#    'location': '9XX FIFTH ST',
#    'locationid': '41010',
#    'neighbourhood': 'Westwood',
#    'neighbourhoodid': '18',
#    'lat': '49.155369',
#    'long': '-123.967743'},
#   {'id': '4201201912598',
#    'file': '2019-12598',
#    'date': ['4/10/2019', '1:35:00', 'PM'],
#    'occurrencetype': 'Theft Other Under $5000',
#    'occurrencetypeid': '2140-13',
#    'crimetype': 'Theft',
#    'crimetypeid': '4',
#    'crimecategory': 'Property Crime',
#    'crimecategoryid': '1',
#    'location': '9XX FIFTH ST',
#    'locationid': '41010',
#    'neighbourhood': 'Westwood',
#    'neighbourhoodid': '18',
#    'lat': '49.155369',
#    'long': '-123.967743'},
#   {'id': '4201201940511',
#    'file': '2019-40511',
#    'date': ['10/7/2019', '3:32:00', 'PM'],
#    'occurrencetype': 'Theft Other Under $5000',
#    'occurrencetypeid': '2140-13',
#    'crimetype': 'Theft',
#    'crimetypeid': '4',
#    'crimecategory': 'Property Crime',
#    'crimecategoryid': '1',
#    'location': '1XX WESTWOOD RD',
#    'locationid': '41294',
#    'neighbourhood': 'Westwood',
#    'neighbourhoodid': '18',
#    'lat': '49.173438',
#    'long': '-123.98601'},
#   {'id': '4201201936590',
#    'file': '2019-36590',
#    'date': ['9/12/2019', '3:10:00', 'AM'],
#    'occurrencetype': 'Theft from Motor Vehicle Under $5000',
#    'occurrencetypeid': '2142-00',
#    'crimetype': 'Theft from Motor Vehicle',
#    'crimetypeid': '5',
#    'crimecategory': 'Property Crime',
#    'crimecategoryid': '1',
#    'location': '10XX NANAIMO LAKES RD',
#    'locationid': '40965',
#    'neighbourhood': 'Westwood',
#    'neighbourhoodid': '18',
#    'lat': '49.143447',
#    'long': '-123.974462'},
#   {'id': '4201201921396',
#    'file': '2019-21396',
#    'date': ['6/8/2019', '7:37:00', 'PM'],
#    'occurrencetype': 'Theft from Motor Vehicle Under $5000',
#    'occurrencetypeid': '2142-00',
#    'crimetype': 'Theft from Motor Vehicle',
#    'crimetypeid': '5',
#    'crimecategory': 'Property Crime',
#    'crimecategoryid': '1',
#    'location': '10XX NANAIMO LAKES RD',
#    'locationid': '40965',
#    'neighbourhood': 'Westwood',
#    'neighbourhoodid': '18',
#    'lat': '49.143447',
#    'long': '-123.974462'},
#   {'id': '4201201917423',
#    'file': '2019-17423',
#    'date': ['5/13/2019', '3:27:00', 'PM'],
#    'occurrencetype': 'Theft from Motor Vehicle Under $5000',
#    'occurrencetypeid': '2142-00',
#    'crimetype': 'Theft from Motor Vehicle',
#    'crimetypeid': '5',
#    'crimecategory': 'Property Crime',
#    'crimecategoryid': '1',
#    'location': '12XX NANAIMO LAKES RD',
#    'locationid': '40968',
#    'neighbourhood': 'Westwood',
#    'neighbourhoodid': '18',
#    'lat': '49.132475',
#    'long': '-123.97503'},
#   {'id': '4201201913827',
#    'file': '2019-13827',
#    'date': ['4/18/2019', '11:00:00', 'PM'],
#    'occurrencetype': 'Theft from Motor Vehicle Under $5000',
#    'occurrencetypeid': '2142-00',
#    'crimetype': 'Theft from Motor Vehicle',
#    'crimetypeid': '5',
#    'crimecategory': 'Property Crime',
#    'crimecategoryid': '1',
#    'location': '19XX CAMAS RD',
#    'locationid': '40971',
#    'neighbourhood': 'Westwood',
#    'neighbourhoodid': '18',
#    'lat': '49.17782',
#    'long': '-123.987601'},
#   {'id': '4201201935339',
#    'file': '2019-35339',
#    'date': ['9/3/2019', '9:52:00', 'PM'],
#    'occurrencetype': 'Theft from Motor Vehicle Under $5000',
#    'occurrencetypeid': '2142-00',
#    'crimetype': 'Theft from Motor Vehicle',
#    'crimetypeid': '5',
#    'crimecategory': 'Property Crime',
#    'crimecategoryid': '1',
#    'location': '1XX CAMROSE PL',
#    'locationid': '40974',
#    'neighbourhood': 'Westwood',
#    'neighbourhoodid': '18',
#    'lat': '49.160583',
#    'long': '-123.973139'},
#   {'id': '4201201916216',
#    'file': '2019-16216',
#    'date': ['5/5/2019', '12:53:00', 'PM'],
#    'occurrencetype': 'Theft from Motor Vehicle Under $5000',
#    'occurrencetypeid': '2142-00',
#    'crimetype': 'Theft from Motor Vehicle',
#    'crimetypeid': '5',
#    'crimecategory': 'Property Crime',
#    'crimecategoryid': '1',
#    'location': '1XX CHELAN PL',
#    'locationid': '40975',
#    'neighbourhood': 'Westwood',
#    'neighbourhoodid': '18',
#    'lat': '49.172568',
#    'long': '-123.991267'},
#   {'id': '4201201937644',
#    'file': '2019-37644',
#    'date': ['9/18/2019', '4:00:00', 'PM'],
#    'occurrencetype': 'Theft from Motor Vehicle Under $5000',
#    'occurrencetypeid': '2142-00',
#    'crimetype': 'Theft from Motor Vehicle',
#    'crimetypeid': '5',
#    'crimecategory': 'Property Crime',
#    'crimecategoryid': '1',
#    'location': '1XX WESTWOOD RD',
#    'locationid': '40978',
#    'neighbourhood': 'Westwood',
#    'neighbourhoodid': '18',
#    'lat': '49.175434',
#    'long': '-123.98607'},
#   {'id': '4201201916230',
#    'file': '2019-16230',
#    'date': ['5/5/2019', '3:26:00', 'PM'],
#    'occurrencetype': 'Theft from Motor Vehicle Under $5000',
#    'occurrencetypeid': '2142-00',
#    'crimetype': 'Theft from Motor Vehicle',
#    'crimetypeid': '5',
#    'crimecategory': 'Property Crime',
#    'crimecategoryid': '1',
#    'location': '20XX CATHER VIEW PL',
#    'locationid': '40979',
#    'neighbourhood': 'Westwood',
#    'neighbourhoodid': '18',
#    'lat': '49.170206',
#    'long': '-123.990028'},
#   {'id': '4201201918143',
#    'file': '2019-18143',
#    'date': ['5/18/2019', '4:08:00', 'AM'],
#    'occurrencetype': 'Theft from Motor Vehicle Under $5000',
#    'occurrencetypeid': '2142-00',
#    'crimetype': 'Theft from Motor Vehicle',
#    'crimetypeid': '5',
#    'crimecategory': 'Property Crime',
#    'crimecategoryid': '1',
#    'location': '20XX CATHERS DR',
#    'locationid': '40980',
#    'neighbourhood': 'Westwood',
#    'neighbourhoodid': '18',
#    'lat': '49.173355',
#    'long': '-123.98726'},
#   {'id': '4201201932006',
#    'file': '2019-32006',
#    'date': ['8/14/2019', '3:01:00', 'AM'],
#    'occurrencetype': 'Theft from Motor Vehicle Under $5000',
#    'occurrencetypeid': '2142-00',
#    'crimetype': 'Theft from Motor Vehicle',
#    'crimetypeid': '5',
#    'crimecategory': 'Property Crime',
#    'crimecategoryid': '1',
#    'location': '20XX EAST WELLINGTON RD',
#    'locationid': '40983',
#    'neighbourhood': 'Westwood',
#    'neighbourhoodid': '18',
#    'lat': '49.180608',
#    'long': '-123.991759'},
#   {'id': '4201201927110',
#    'file': '2019-27110',
#    'date': ['7/13/2019', '4:16:00', 'PM'],
#    'occurrencetype': 'Theft from Motor Vehicle Under $5000',
#    'occurrencetypeid': '2142-00',
#    'crimetype': 'Theft from Motor Vehicle',
#    'crimetypeid': '5',
#    'crimecategory': 'Property Crime',
#    'crimecategoryid': '1',
#    'location': '21XX SALMON RD',
#    'locationid': '40987',
#    'neighbourhood': 'Westwood',
#    'neighbourhoodid': '18',
#    'lat': '49.167975',
#    'long': '-123.985438'},
#   {'id': '4201201931613',
#    'file': '2019-31613',
#    'date': ['8/11/2019', '12:22:00', 'PM'],
#    'occurrencetype': 'Theft from Motor Vehicle Under $5000',
#    'occurrencetypeid': '2142-00',
#    'crimetype': 'Theft from Motor Vehicle',
#    'crimetypeid': '5',
#    'crimecategory': 'Property Crime',
#    'crimecategoryid': '1',
#    'location': '21XX WOODTHRUSH PL',
#    'locationid': '40988',
#    'neighbourhood': 'Westwood',
#    'neighbourhoodid': '18',
#    'lat': '49.165241',
#    'long': '-123.988828'},
#   {'id': '4201201939325',
#    'file': '2019-39325',
#    'date': ['9/28/2019', '10:00:00', 'PM'],
#    'occurrencetype': 'Theft from Motor Vehicle Under $5000',
#    'occurrencetypeid': '2142-00',
#    'crimetype': 'Theft from Motor Vehicle',
#    'crimetypeid': '5',
#    'crimecategory': 'Property Crime',
#    'crimecategoryid': '1',
#    'location': '22XX ARBOT RD',
#    'locationid': '40990',
#    'neighbourhood': 'Westwood',
#    'neighbourhoodid': '18',
#    'lat': '49.166632',
#    'long': '-123.986719'},
#   {'id': '4201201938970',
#    'file': '2019-38970',
#    'date': ['9/27/2019', '8:12:00', 'AM'],
#    'occurrencetype': 'Theft from Motor Vehicle Under $5000',
#    'occurrencetypeid': '2142-00',
#    'crimetype': 'Theft from Motor Vehicle',
#    'crimetypeid': '5',
#    'crimecategory': 'Property Crime',
#    'crimecategoryid': '1',
#    'location': '22XX ARBOT RD',
#    'locationid': '40990',
#    'neighbourhood': 'Westwood',
#    'neighbourhoodid': '18',
#    'lat': '49.166632',
#    'long': '-123.986719'},
#   {'id': '4201201926945',
#    'file': '2019-26945',
#    'date': ['7/13/2019', '1:07:00', 'PM'],
#    'occurrencetype': 'Theft from Motor Vehicle Under $5000',
#    'occurrencetypeid': '2142-00',
#    'crimetype': 'Theft from Motor Vehicle',
#    'crimetypeid': '5',
#    'crimecategory': 'Property Crime',
#    'crimecategoryid': '1',
#    'location': '22XX DOCKSIDE WAY',
#    'locationid': '40993',
#    'neighbourhood': 'Westwood',
#    'neighbourhoodid': '18',
#    'lat': '49.172583',
#    'long': '-123.996331'},
#   {'id': '4201201935238',
#    'file': '2019-35238',
#    'date': ['9/3/2019', '10:30:00', 'AM'],
#    'occurrencetype': 'Theft from Motor Vehicle Under $5000',
#    'occurrencetypeid': '2142-00',
#    'crimetype': 'Theft from Motor Vehicle',
#    'crimetypeid': '5',
#    'crimecategory': 'Property Crime',
#    'crimecategoryid': '1',
#    'location': '24XX JINGLE POT RD',
#    'locationid': '40998',
#    'neighbourhood': 'Westwood',
#    'neighbourhoodid': '18',
#    'lat': '49.172114',
#    'long': '-124.007959'},
#   {'id': '4201201918053',
#    'file': '2019-18053',
#    'date': ['5/17/2019', '2:33:00', 'PM'],
#    'occurrencetype': 'Theft from Motor Vehicle Under $5000',
#    'occurrencetypeid': '2142-00',
#    'crimetype': 'Theft from Motor Vehicle',
#    'crimetypeid': '5',
#    'crimecategory': 'Property Crime',
#    'crimecategoryid': '1',
#    'location': '2XX HARWELL RD',
#    'locationid': '40999',
#    'neighbourhood': 'Westwood',
#    'neighbourhoodid': '18',
#    'lat': '49.168466',
#    'long': '-123.988099'},
#   {'id': '4201201936148',
#    'file': '2019-36148',
#    'date': ['9/8/2019', '8:00:00', 'PM'],
#    'occurrencetype': 'Theft from Motor Vehicle Under $5000',
#    'occurrencetypeid': '2142-00',
#    'crimetype': 'Theft from Motor Vehicle',
#    'crimetypeid': '5',
#    'crimecategory': 'Property Crime',
#    'crimecategoryid': '1',
#    'location': '2XX TAHOE AVE',
#    'locationid': '41001',
#    'neighbourhood': 'Westwood',
#    'neighbourhoodid': '18',
#    'lat': '49.171507',
#    'long': '-123.989015'},
#   {'id': '4201201934575',
#    'file': '2019-34575',
#    'date': ['8/29/2019', '9:31:00', 'PM'],
#    'occurrencetype': 'Theft from Motor Vehicle Under $5000',
#    'occurrencetypeid': '2142-00',
#    'crimetype': 'Theft from Motor Vehicle',
#    'crimetypeid': '5',
#    'crimecategory': 'Property Crime',
#    'crimecategoryid': '1',
#    'location': '2XX TAHOE AVE',
#    'locationid': '41001',
#    'neighbourhood': 'Westwood',
#    'neighbourhoodid': '18',
#    'lat': '49.171507',
#    'long': '-123.989015'},
#   {'id': '4201201917694',
#    'file': '2019-17694',
#    'date': ['5/15/2019', '9:32:00', 'AM'],
#    'occurrencetype': 'Theft from Motor Vehicle Under $5000',
#    'occurrencetypeid': '2142-00',
#    'crimetype': 'Theft from Motor Vehicle',
#    'crimetypeid': '5',
#    'crimecategory': 'Property Crime',
#    'crimecategoryid': '1',
#    'location': '2XX TAHOE AVE',
#    'locationid': '41002',
#    'neighbourhood': 'Westwood',
#    'neighbourhoodid': '18',
#    'lat': '49.173101',
#    'long': '-123.990099'},
#   {'id': '4201201917700',
#    'file': '2019-17700',
#    'date': ['5/15/2019', '10:20:00', 'AM'],
#    'occurrencetype': 'Theft from Motor Vehicle Under $5000',
#    'occurrencetypeid': '2142-00',
#    'crimetype': 'Theft from Motor Vehicle',
#    'crimetypeid': '5',
#    'crimecategory': 'Property Crime',
#    'crimecategoryid': '1',
#    'location': '3XX HARWELL RD',
#    'locationid': '41006',
#    'neighbourhood': 'Westwood',
#    'neighbourhoodid': '18',
#    'lat': '49.16371',
#    'long': '-123.990839'},
#   {'id': '4201201920912',
#    'file': '2019-20912',
#    'date': ['6/5/2019', '2:09:00', 'PM'],
#    'occurrencetype': 'Theft from Motor Vehicle Under $5000',
#    'occurrencetypeid': '2142-00',
#    'crimetype': 'Theft from Motor Vehicle',
#    'crimetypeid': '5',
#    'crimecategory': 'Property Crime',
#    'crimecategoryid': '1',
#    'location': '3XX WESTWOOD RD',
#    'locationid': '41007',
#    'neighbourhood': 'Westwood',
#    'neighbourhoodid': '18',
#    'lat': '49.164091',
#    'long': '-123.996686'},
#   {'id': '4201201920716',
#    'file': '2019-20716',
#    'date': ['6/4/2019', '9:18:00', 'AM'],
#    'occurrencetype': 'Theft from Motor Vehicle Under $5000',
#    'occurrencetypeid': '2142-00',
#    'crimetype': 'Theft from Motor Vehicle',
#    'crimetypeid': '5',
#    'crimecategory': 'Property Crime',
#    'crimecategoryid': '1',
#    'location': '5XX WAKESIAH AVE',
#    'locationid': '41008',
#    'neighbourhood': 'Westwood',
#    'neighbourhoodid': '18',
#    'lat': '49.154242',
#    'long': '-123.961119'},
#   {'id': '4201201937496',
#    'file': '2019-37496',
#    'date': ['9/17/2019', '6:26:00', 'PM'],
#    'occurrencetype': 'Theft from Motor Vehicle Under $5000',
#    'occurrencetypeid': '2142-00',
#    'crimetype': 'Theft from Motor Vehicle',
#    'crimetypeid': '5',
#    'crimecategory': 'Property Crime',
#    'crimecategoryid': '1',
#    'location': '9XX FIFTH ST',
#    'locationid': '41010',
#    'neighbourhood': 'Westwood',
#    'neighbourhoodid': '18',
#    'lat': '49.155369',
#    'long': '-123.967743'},
#   {'id': '4201201929782',
#    'file': '2019-29782',
#    'date': ['7/30/2019', '9:00:00', 'AM'],
#    'occurrencetype': 'Theft from Motor Vehicle Under $5000',
#    'occurrencetypeid': '2142-00',
#    'crimetype': 'Theft from Motor Vehicle',
#    'crimetypeid': '5',
#    'crimecategory': 'Property Crime',
#    'crimecategoryid': '1',
#    'location': '9XX FIFTH ST',
#    'locationid': '41010',
#    'neighbourhood': 'Westwood',
#    'neighbourhoodid': '18',
#    'lat': '49.155369',
#    'long': '-123.967743'},
#   {'id': '4201201928490',
#    'file': '2019-28490',
#    'date': ['7/16/2019', '12:01:00', 'AM'],
#    'occurrencetype': 'Theft from Motor Vehicle Under $5000',
#    'occurrencetypeid': '2142-00',
#    'crimetype': 'Theft from Motor Vehicle',
#    'crimetypeid': '5',
#    'crimecategory': 'Property Crime',
#    'crimecategoryid': '1',
#    'location': '9XX FIFTH ST',
#    'locationid': '41010',
#    'neighbourhood': 'Westwood',
#    'neighbourhoodid': '18',
#    'lat': '49.155369',
#    'long': '-123.967743'},
#   {'id': '4201201924086',
#    'file': '2019-24086',
#    'date': ['6/24/2019', '10:00:00', 'PM'],
#    'occurrencetype': 'Theft from Motor Vehicle Under $5000',
#    'occurrencetypeid': '2142-00',
#    'crimetype': 'Theft from Motor Vehicle',
#    'crimetypeid': '5',
#    'crimecategory': 'Property Crime',
#    'crimecategoryid': '1',
#    'location': '9XX FIFTH ST',
#    'locationid': '41010',
#    'neighbourhood': 'Westwood',
#    'neighbourhoodid': '18',
#    'lat': '49.155369',
#    'long': '-123.967743'},
#   {'id': '4201201921073',
#    'file': '2019-21073',
#    'date': ['6/6/2019', '3:10:00', 'PM'],
#    'occurrencetype': 'Theft from Motor Vehicle Under $5000',
#    'occurrencetypeid': '2142-00',
#    'crimetype': 'Theft from Motor Vehicle',
#    'crimetypeid': '5',
#    'crimecategory': 'Property Crime',
#    'crimecategoryid': '1',
#    'location': '9XX FIFTH ST',
#    'locationid': '41010',
#    'neighbourhood': 'Westwood',
#    'neighbourhoodid': '18',
#    'lat': '49.155369',
#    'long': '-123.967743'},
#   {'id': '4201201914087',
#    'file': '2019-14087',
#    'date': ['4/19/2019', '10:38:00', 'AM'],
#    'occurrencetype': 'Theft from Motor Vehicle Under $5000',
#    'occurrencetypeid': '2142-00',
#    'crimetype': 'Theft from Motor Vehicle',
#    'crimetypeid': '5',
#    'crimecategory': 'Property Crime',
#    'crimecategoryid': '1',
#    'location': '9XX FIFTH ST',
#    'locationid': '41010',
#    'neighbourhood': 'Westwood',
#    'neighbourhoodid': '18',
#    'lat': '49.155369',
#    'long': '-123.967743'},
#   {'id': '4201201932288',
#    'file': '2019-32288',
#    'date': ['8/15/2019', '6:45:00', 'PM'],
#    'occurrencetype': 'Theft from Motor Vehicle Under $5000',
#    'occurrencetypeid': '2142-00',
#    'crimetype': 'Theft from Motor Vehicle',
#    'crimetypeid': '5',
#    'crimecategory': 'Property Crime',
#    'crimecategoryid': '1',
#    'location': 'NANAIMO LAKES RD / ACCESS RD',
#    'locationid': '41015',
#    'neighbourhood': 'Westwood',
#    'neighbourhoodid': '18',
#    'lat': '49.137822',
#    'long': '-123.974346'},
#   {'id': '4201201935454',
#    'file': '2019-35454',
#    'date': ['9/4/2019', '4:34:00', 'PM'],
#    'occurrencetype': 'Theft from Motor Vehicle Under $5000',
#    'occurrencetypeid': '2142-00',
#    'crimetype': 'Theft from Motor Vehicle',
#    'crimetypeid': '5',
#    'crimecategory': 'Property Crime',
#    'crimecategoryid': '1',
#    'location': 'WESTWOOD RD / MARLENE PL',
#    'locationid': '41017',
#    'neighbourhood': 'Westwood',
#    'neighbourhoodid': '18',
#    'lat': '49.16368',
#    'long': '-123.996692'},
#   {'id': '4201201939927',
#    'file': '2019-39927',
#    'date': ['10/3/2019', '12:11:00', 'PM'],
#    'occurrencetype': 'Theft from Motor Vehicle Under $5000',
#    'occurrencetypeid': '2142-00',
#    'crimetype': 'Theft from Motor Vehicle',
#    'crimetypeid': '5',
#    'crimecategory': 'Property Crime',
#    'crimecategoryid': '1',
#    'location': '3XX HARWELL RD',
#    'locationid': '41295',
#    'neighbourhood': 'Westwood',
#    'neighbourhoodid': '18',
#    'lat': '49.166089',
#    'long': '-123.989639'},
#   {'id': '4201201939964',
#    'file': '2019-39964',
#    'date': ['10/3/2019', '4:14:00', 'PM'],
#    'occurrencetype': 'Theft from Motor Vehicle Under $5000',
#    'occurrencetypeid': '2142-00',
#    'crimetype': 'Theft from Motor Vehicle',
#    'crimetypeid': '5',
#    'crimecategory': 'Property Crime',
#    'crimecategoryid': '1',
#    'location': '7XX DOGWOOD RD',
#    'locationid': '41296',
#    'neighbourhood': 'Westwood',
#    'neighbourhoodid': '18',
#    'lat': '49.149048',
#    'long': '-123.97337'},
#   {'id': '4201201937618',
#    'file': '2019-37618',
#    'date': ['9/18/2019', '4:30:00', 'PM'],
#    'occurrencetype': 'Mischief Under $5000',
#    'occurrencetypeid': '2170-04',
#    'crimetype': 'Mischief',
#    'crimetypeid': '2',
#    'crimecategory': 'Property Crime',
#    'crimecategoryid': '1',
#    'location': '11XX NANAIMO LAKES RD',
#    'locationid': '40966',
#    'neighbourhood': 'Westwood',
#    'neighbourhoodid': '18',
#    'lat': '49.138078',
#    'long': '-123.974302'},
#   {'id': '4201201932586',
#    'file': '2019-32586',
#    'date': ['8/17/2019', '8:12:00', 'PM'],
#    'occurrencetype': 'Mischief Under $5000',
#    'occurrencetypeid': '2170-04',
#    'crimetype': 'Mischief',
#    'crimetypeid': '2',
#    'crimecategory': 'Property Crime',
#    'crimecategoryid': '1',
#    'location': '1XX HOLLAND RD',
#    'locationid': '40976',
#    'neighbourhood': 'Westwood',
#    'neighbourhoodid': '18',
#    'lat': '49.172661',
#    'long': '-123.999485'},
#   {'id': '4201201936938',
#    'file': '2019-36938',
#    'date': ['9/14/2019', '10:48:00', 'AM'],
#    'occurrencetype': 'Mischief Under $5000',
#    'occurrencetypeid': '2170-04',
#    'crimetype': 'Mischief',
#    'crimetypeid': '2',
#    'crimecategory': 'Property Crime',
#    'crimecategoryid': '1',
#    'location': '20XX CATHERS DR',
#    'locationid': '40981',
#    'neighbourhood': 'Westwood',
#    'neighbourhoodid': '18',
#    'lat': '49.173484',
#    'long': '-123.989106'},
#   {'id': '4201201940510',
#    'file': '2019-40510',
#    'date': ['10/7/2019', '3:22:00', 'PM'],
#    'occurrencetype': 'Mischief Under $5000',
#    'occurrencetypeid': '2170-04',
#    'crimetype': 'Mischief',
#    'crimetypeid': '2',
#    'crimecategory': 'Property Crime',
#    'crimecategoryid': '1',
#    'location': '21XX EAST WELLINGTON RD',
#    'locationid': '40985',
#    'neighbourhood': 'Westwood',
#    'neighbourhoodid': '18',
#    'lat': '49.181413',
#    'long': '-123.994643'},
#   {'id': '4201201928133',
#    'file': '2019-28133',
#    'date': ['7/20/2019', '9:04:00', 'PM'],
#    'occurrencetype': 'Mischief Under $5000',
#    'occurrencetypeid': '2170-04',
#    'crimetype': 'Mischief',
#    'crimetypeid': '2',
#    'crimecategory': 'Property Crime',
#    'crimecategoryid': '1',
#    'location': '22XX  JINGLE POT RD',
#    'locationid': '40989',
#    'neighbourhood': 'Westwood',
#    'neighbourhoodid': '18',
#    'lat': '49.169152',
#    'long': '-123.987229'},
#   {'id': '4201201913013',
#    'file': '2019-13013',
#    'date': ['4/13/2019', '3:35:00', 'PM'],
#    'occurrencetype': 'Mischief Under $5000',
#    'occurrencetypeid': '2170-04',
#    'crimetype': 'Mischief',
#    'crimetypeid': '2',
#    'crimecategory': 'Property Crime',
#    'crimecategoryid': '1',
#    'location': '22XX BELWOOD RD',
#    'locationid': '40992',
#    'neighbourhood': 'Westwood',
#    'neighbourhoodid': '18',
#    'lat': '49.165266',
#    'long': '-123.997381'},
#   {'id': '4201201939063',
#    'file': '2019-39063',
#    'date': ['9/27/2019', '6:04:00', 'PM'],
#    'occurrencetype': 'Mischief Under $5000',
#    'occurrencetypeid': '2170-04',
#    'crimetype': 'Mischief',
#    'crimetypeid': '2',
#    'crimecategory': 'Property Crime',
#    'crimecategoryid': '1',
#    'location': '23XX ARBOT RD',
#    'locationid': '40995',
#    'neighbourhood': 'Westwood',
#    'neighbourhoodid': '18',
#    'lat': '49.166684',
#    'long': '-124.000721'},
#   {'id': '4201201937917',
#    'file': '2019-37917',
#    'date': ['9/20/2019', '11:45:00', 'AM'],
#    'occurrencetype': 'Mischief Under $5000',
#    'occurrencetypeid': '2170-04',
#    'crimetype': 'Mischief',
#    'crimetypeid': '2',
#    'crimecategory': 'Property Crime',
#    'crimecategoryid': '1',
#    'location': '23XX TOWERVIEW CRES',
#    'locationid': '40997',
#    'neighbourhood': 'Westwood',
#    'neighbourhoodid': '18',
#    'lat': '49.169633',
#    'long': '-124.001525'},
#   {'id': '4201201914817',
#    'file': '2019-14817',
#    'date': ['4/26/2019', '10:32:00', 'AM'],
#    'occurrencetype': 'Mischief Under $5000',
#    'occurrencetypeid': '2170-04',
#    'crimetype': 'Mischief',
#    'crimetypeid': '2',
#    'crimecategory': 'Property Crime',
#    'crimecategoryid': '1',
#    'location': '2XX HARWELL RD',
#    'locationid': '41000',
#    'neighbourhood': 'Westwood',
#    'neighbourhoodid': '18',
#    'lat': '49.168956',
#    'long': '-123.98869'},
#   {'id': '4201201919326',
#    'file': '2019-19326',
#    'date': ['5/26/2019', '5:52:00', 'AM'],
#    'occurrencetype': 'Mischief Under $5000',
#    'occurrencetypeid': '2170-04',
#    'crimetype': 'Mischief',
#    'crimetypeid': '2',
#    'crimecategory': 'Property Crime',
#    'crimecategoryid': '1',
#    'location': '3XX CAMOSUN DR',
#    'locationid': '41005',
#    'neighbourhood': 'Westwood',
#    'neighbourhoodid': '18',
#    'lat': '49.161417',
#    'long': '-123.981831'},
#   {'id': '4201201920221',
#    'file': '2019-20221',
#    'date': ['5/31/2019', '4:36:00', 'PM'],
#    'occurrencetype': 'Mischief Under $5000',
#    'occurrencetypeid': '2170-04',
#    'crimetype': 'Mischief',
#    'crimetypeid': '2',
#    'crimecategory': 'Property Crime',
#    'crimecategoryid': '1',
#    'location': '7XX NANAIMO LAKES RD',
#    'locationid': '41009',
#    'neighbourhood': 'Westwood',
#    'neighbourhoodid': '18',
#    'lat': '49.145961',
#    'long': '-123.973515'},
#   {'id': '4201201926504',
#    'file': '2019-26504',
#    'date': ['7/10/2019', '7:00:00', 'PM'],
#    'occurrencetype': 'Mischief Under $5000',
#    'occurrencetypeid': '2170-04',
#    'crimetype': 'Mischief',
#    'crimetypeid': '2',
#    'crimecategory': 'Property Crime',
#    'crimecategoryid': '1',
#    'location': 'DOCKSIDE WAY / VILLAGE LAND',
#    'locationid': '41011',
#    'neighbourhood': 'Westwood',
#    'neighbourhoodid': '18',
#    'lat': '49.171825',
#    'long': '-123.994519'},
#   {'id': '4201201918243',
#    'file': '2019-18243',
#    'date': ['5/18/2019', '10:27:00', 'PM'],
#    'occurrencetype': 'Mischief Under $5000',
#    'occurrencetypeid': '2170-04',
#    'crimetype': 'Mischief',
#    'crimetypeid': '2',
#    'crimecategory': 'Property Crime',
#    'crimecategoryid': '1',
#    'location': 'LANGARA DR / CAMOSUN DR',
#    'locationid': '41014',
#    'neighbourhood': 'Westwood',
#    'neighbourhoodid': '18',
#    'lat': '49.161052',
#    'long': '-123.981816'},
#   {'id': '4201201923184',
#    'file': '2019-23184',
#    'date': ['6/19/2019', '6:51:00', 'PM'],
#    'occurrencetype': 'Mischief Under $5000',
#    'occurrencetypeid': '2170-04',
#    'crimetype': 'Mischief',
#    'crimetypeid': '2',
#    'crimecategory': 'Property Crime',
#    'crimecategoryid': '1',
#    'location': 'NANAIMO PKWY / FIFTH ST',
#    'locationid': '41016',
#    'neighbourhood': 'Westwood',
#    'neighbourhoodid': '18',
#    'lat': '49.15441',
#    'long': '-123.971953'},
#   {'id': '4201201919281',
#    'file': '2019-19281',
#    'date': ['5/25/2019', '8:19:00', 'PM'],
#    'occurrencetype': 'Mischief Under $5000',
#    'occurrencetypeid': '2170-04',
#    'crimetype': 'Mischief',
#    'crimetypeid': '2',
#    'crimecategory': 'Property Crime',
#    'crimecategoryid': '1',
#    'location': 'WESTWOOD RD / PARK ACCESS RD',
#    'locationid': '41018',
#    'neighbourhood': 'Westwood',
#    'neighbourhoodid': '18',
#    'lat': '49.178028',
#    'long': '-123.986754'},
#   {'id': '4201201921450',
#    'file': '2019-21450',
#    'date': ['6/9/2019', '9:19:00', 'AM'],
#    'occurrencetype': 'Mischief - Loss of Enjoyment of Property',
#    'occurrencetypeid': '2170-05',
#    'crimetype': 'Mischief',
#    'crimetypeid': '2',
#    'crimecategory': 'Property Crime',
#    'crimecategoryid': '1',
#    'location': '12XX COLLEGE DR',
#    'locationid': '40967',
#    'neighbourhood': 'Westwood',
#    'neighbourhoodid': '18',
#    'lat': '49.162135',
#    'long': '-123.980651'},
#   {'id': '4201201934448',
#    'file': '2019-34448',
#    'date': ['8/29/2019', '2:55:00', 'AM'],
#    'occurrencetype': 'Mischief - Loss of Enjoyment of Property',
#    'occurrencetypeid': '2170-05',
#    'crimetype': 'Mischief',
#    'crimetypeid': '2',
#    'crimecategory': 'Property Crime',
#    'crimecategoryid': '1',
#    'location': '21XX MICHIGAN WAY',
#    'locationid': '40986',
#    'neighbourhood': 'Westwood',
#    'neighbourhoodid': '18',
#    'lat': '49.173631',
#    'long': '-123.994517'},
#   {'id': '4201201918370',
#    'file': '2019-18370',
#    'date': ['5/19/2019', '11:17:00', 'PM'],
#    'occurrencetype': 'Mischief - Loss of Enjoyment of Property',
#    'occurrencetypeid': '2170-05',
#    'crimetype': 'Mischief',
#    'crimetypeid': '2',
#    'crimecategory': 'Property Crime',
#    'crimecategoryid': '1',
#    'location': '22XX ARBOT RD',
#    'locationid': '40991',
#    'neighbourhood': 'Westwood',
#    'neighbourhoodid': '18',
#    'lat': '49.166665',
#    'long': '-123.998524'},
#   {'id': '4201201917163',
#    'file': '2019-17163',
#    'date': ['5/11/2019', '9:57:00', 'PM'],
#    'occurrencetype': 'Mischief - Loss of Enjoyment of Property',
#    'occurrencetypeid': '2170-05',
#    'crimetype': 'Mischief',
#    'crimetypeid': '2',
#    'crimecategory': 'Property Crime',
#    'crimecategoryid': '1',
#    'location': '22XX ARBOT RD',
#    'locationid': '40991',
#    'neighbourhood': 'Westwood',
#    'neighbourhoodid': '18',
#    'lat': '49.166665',
#    'long': '-123.998524'},
#   {'id': '4201201925295',
#    'file': '2019-25295',
#    'date': ['7/3/2019', '9:18:00', 'AM'],
#    'occurrencetype': 'Mischief - Loss of Enjoyment of Property',
#    'occurrencetypeid': '2170-05',
#    'crimetype': 'Mischief',
#    'crimetypeid': '2',
#    'crimecategory': 'Property Crime',
#    'crimecategoryid': '1',
#    'location': '22XX JINGLE POT RD',
#    'locationid': '40994',
#    'neighbourhood': 'Westwood',
#    'neighbourhoodid': '18',
#    'lat': '49.169152',
#    'long': '-123.987229'},
#   {'id': '4201201937338',
#    'file': '2019-37338',
#    'date': ['9/16/2019', '7:46:00', 'PM'],
#    'occurrencetype': 'Mischief - Loss of Enjoyment of Property',
#    'occurrencetypeid': '2170-05',
#    'crimetype': 'Mischief',
#    'crimetypeid': '2',
#    'crimecategory': 'Property Crime',
#    'crimecategoryid': '1',
#    'location': '23XX TOWERVIEW CRES',
#    'locationid': '40997',
#    'neighbourhood': 'Westwood',
#    'neighbourhoodid': '18',
#    'lat': '49.169633',
#    'long': '-124.001525'},
#   {'id': '4201201938180',
#    'file': '2019-38180',
#    'date': ['9/22/2019', '4:19:00', 'AM'],
#    'occurrencetype': 'Mischief - Loss of Enjoyment of Property',
#    'occurrencetypeid': '2170-05',
#    'crimetype': 'Mischief',
#    'crimetypeid': '2',
#    'crimecategory': 'Property Crime',
#    'crimecategoryid': '1',
#    'location': '5XX WAKESIAH AVE',
#    'locationid': '41008',
#    'neighbourhood': 'Westwood',
#    'neighbourhoodid': '18',
#    'lat': '49.154242',
#    'long': '-123.961119'},
#   {'id': '4201201916755',
#    'file': '2019-16755',
#    'date': ['5/9/2019', '3:40:00', 'AM'],
#    'occurrencetype': 'Mischief - Loss of Enjoyment of Property',
#    'occurrencetypeid': '2170-05',
#    'crimetype': 'Mischief',
#    'crimetypeid': '2',
#    'crimecategory': 'Property Crime',
#    'crimecategoryid': '1',
#    'location': '5XX WAKESIAH AVE',
#    'locationid': '41008',
#    'neighbourhood': 'Westwood',
#    'neighbourhoodid': '18',
#    'lat': '49.154242',
#    'long': '-123.961119'},
#   {'id': '4201201915066',
#    'file': '2019-15066',
#    'date': ['4/27/2019', '6:18:00', 'PM'],
#    'occurrencetype': 'Mischief - Loss of Enjoyment of Property',
#    'occurrencetypeid': '2170-05',
#    'crimetype': 'Mischief',
#    'crimetypeid': '2',
#    'crimecategory': 'Property Crime',
#    'crimecategoryid': '1',
#    'location': '5XX WAKESIAH AVE',
#    'locationid': '41008',
#    'neighbourhood': 'Westwood',
#    'neighbourhoodid': '18',
#    'lat': '49.154242',
#    'long': '-123.961119'}],
#  'Harewood': [{'id': '4201201928011',
#    'file': '2019-28011',
#    'date': ['7/20/2019', '2:53:00', 'AM'],
#    'occurrencetype': 'Commercial Break and Enter',
#    'occurrencetypeid': '2120-01',
#    'crimetype': 'Break and Enter',
#    'crimetypeid': '1',
#    'crimecategory': 'Property Crime',
#    'crimecategoryid': '1',
#    'location': '6XX BRUCE AVE',
#    'locationid': '40214',
#    'neighbourhood': 'Harewood',
#    'neighbourhoodid': '10',
#    'lat': '49.154181',
#    'long': '-123.949571'},
#   {'id': '4201201925896',
#    'file': '2019-25896',
#    'date': ['7/7/2019', '12:35:00', 'AM'],
#    'occurrencetype': 'Commercial Break and Enter',
#    'occurrencetypeid': '2120-01',
#    'crimetype': 'Break and Enter',
#    'crimetypeid': '1',
#    'crimecategory': 'Property Crime',
#    'crimecategoryid': '1',
#    'location': '6XX BRUCE AVE',
#    'locationid': '40214',
#    'neighbourhood': 'Harewood',
#    'neighbourhoodid': '10',
#    'lat': '49.154181',
#    'long': '-123.949571'},
#   {'id': '4201201921463',
#    'file': '2019-21463',
#    'date': ['6/8/2019', '9:15:00', 'AM'],
#    'occurrencetype': 'Commercial Break and Enter',
#    'occurrencetypeid': '2120-01',
#    'crimetype': 'Break and Enter',
#    'crimetypeid': '1',
#    'crimecategory': 'Property Crime',
#    'crimecategoryid': '1',
#    'location': '8XX BRUCE AVE',
#    'locationid': '40247',
#    'neighbourhood': 'Harewood',
#    'neighbourhoodid': '10',
#    'lat': '49.1447',
#    'long': '-123.949655'},
#   {'id': '4201201919074',
#    'file': '2019-19074',
#    'date': ['5/23/2019', '10:00:00', 'PM'],
#    'occurrencetype': 'Commercial Break and Enter',
#    'occurrencetypeid': '2120-01',
#    'crimetype': 'Break and Enter',
#    'crimetypeid': '1',
#    'crimecategory': 'Property Crime',
#    'crimecategoryid': '1',
#    'location': 'XX TENTH ST',
#    'locationid': '40295',
#    'neighbourhood': 'Harewood',
#    'neighbourhoodid': '10',
#    'lat': '49.130855',
#    'long': '-123.923303'},
#   {'id': '4201201925302',
#    'file': '2019-25302',
#    'date': ['7/2/2019', '10:00:00', 'PM'],
#    'occurrencetype': 'Residential Break and Enter',
#    'occurrencetypeid': '2120-02',
#    'crimetype': 'Break and Enter',
#    'crimetypeid': '1',
#    'crimecategory': 'Property Crime',
#    'crimecategoryid': '1',
#    'location': '10XX SHELBY ANN AVE',
#    'locationid': '40142',
#    'neighbourhood': 'Harewood',
#    'neighbourhoodid': '10',
#    'lat': '49.137033',
#    'long': '-123.951089'},
#   {'id': '4201201925279',
#    'file': '2019-25279',
#    'date': ['7/2/2019', '11:00:00', 'PM'],
#    'occurrencetype': 'Residential Break and Enter',
#    'occurrencetypeid': '2120-02',
#    'crimetype': 'Break and Enter',
#    'crimetypeid': '1',
#    'crimecategory': 'Property Crime',
#    'crimecategoryid': '1',
#    'location': '10XX SHELBY ANN AVE',
#    'locationid': '40143',
#    'neighbourhood': 'Harewood',
#    'neighbourhoodid': '10',
#    'lat': '49.138097',
#    'long': '-123.952169'},
#   {'id': '4201201919135',
#    'file': '2019-19135',
#    'date': ['5/24/2019', '4:43:00', 'PM'],
#    'occurrencetype': 'Residential Break and Enter',
#    'occurrencetypeid': '2120-02',
#    'crimetype': 'Break and Enter',
#    'crimetypeid': '1',
#    'crimecategory': 'Property Crime',
#    'crimecategoryid': '1',
#    'location': '2XX SEVENTH ST',
#    'locationid': '40157',
#    'neighbourhood': 'Harewood',
#    'neighbourhoodid': '10',
#    'lat': '49.147488',
#    'long': '-123.939375'},
#   {'id': '4201201917217',
#    'file': '2019-17217',
#    'date': ['5/10/2019', '8:00:00', 'AM'],
#    'occurrencetype': 'Residential Break and Enter',
#    'occurrencetypeid': '2120-02',
#    'crimetype': 'Break and Enter',
#    'crimetypeid': '1',
#    'crimecategory': 'Property Crime',
#    'crimecategoryid': '1',
#    'location': '2XX SEVENTH ST',
#    'locationid': '40157',
#    'neighbourhood': 'Harewood',
#    'neighbourhoodid': '10',
#    'lat': '49.147488',
#    'long': '-123.939375'},
#   {'id': '4201201923124',
#    'file': '2019-23124',
#    'date': ['6/19/2019', '1:23:00', 'PM'],
#    'occurrencetype': 'Residential Break and Enter',
#    'occurrencetypeid': '2120-02',
#    'crimetype': 'Break and Enter',
#    'crimetypeid': '1',
#    'crimecategory': 'Property Crime',
#    'crimecategoryid': '1',
#    'location': '4XX HEWGATE ST',
#    'locationid': '40181',
#    'neighbourhood': 'Harewood',
#    'neighbourhoodid': '10',
#    'lat': '49.149413',
#    'long': '-123.948419'},
#   {'id': '4201201929900',
#    'file': '2019-29900',
#    'date': ['7/30/2019', '8:00:00', 'PM'],
#    'occurrencetype': 'Residential Break and Enter',
#    'occurrencetypeid': '2120-02',
#    'crimetype': 'Break and Enter',
#    'crimetypeid': '1',
#    'crimecategory': 'Property Crime',
#    'crimecategoryid': '1',
#    'location': '4XX SEVENTH ST',
#    'locationid': '40185',
#    'neighbourhood': 'Harewood',
#    'neighbourhoodid': '10',
#    'lat': '49.147541',
#    'long': '-123.948179'},
#   {'id': '4201201937429',
#    'file': '2019-37429',
#    'date': ['9/16/2019', '10:00:00', 'PM'],
#    'occurrencetype': 'Residential Break and Enter',
#    'occurrencetypeid': '2120-02',
#    'crimetype': 'Break and Enter',
#    'crimetypeid': '1',
#    'crimecategory': 'Property Crime',
#    'crimecategoryid': '1',
#    'location': '4XX TENTH ST',
#    'locationid': '40187',
#    'neighbourhood': 'Harewood',
#    'neighbourhoodid': '10',
#    'lat': '49.136119',
#    'long': '-123.946822'},
#   {'id': '4201201928843',
#    'file': '2019-28843',
#    'date': ['7/25/2019', '3:10:00', 'AM'],
#    'occurrencetype': 'Residential Break and Enter',
#    'occurrencetypeid': '2120-02',
#    'crimetype': 'Break and Enter',
#    'crimetypeid': '1',
#    'crimecategory': 'Property Crime',
#    'crimecategoryid': '1',
#    'location': '5XX FIFTH ST',
#    'locationid': '40196',
#    'neighbourhood': 'Harewood',
#    'neighbourhoodid': '10',
#    'lat': '49.155147',
#    'long': '-123.953135'},
#   {'id': '4201201925449',
#    'file': '2019-25449',
#    'date': ['7/4/2019', '7:48:00', 'AM'],
#    'occurrencetype': 'Residential Break and Enter',
#    'occurrencetypeid': '2120-02',
#    'crimetype': 'Break and Enter',
#    'crimetypeid': '1',
#    'crimecategory': 'Property Crime',
#    'crimecategoryid': '1',
#    'location': '5XX GREWAL PL',
#    'locationid': '40197',
#    'neighbourhood': 'Harewood',
#    'neighbourhoodid': '10',
#    'lat': '49.139185',
#    'long': '-123.953861'},
#   {'id': '4201201928537',
#    'file': '2019-28537',
#    'date': ['7/23/2019', '7:00:00', 'AM'],
#    'occurrencetype': 'Residential Break and Enter',
#    'occurrencetypeid': '2120-02',
#    'crimetype': 'Break and Enter',
#    'crimetypeid': '1',
#    'crimecategory': 'Property Crime',
#    'crimecategoryid': '1',
#    'location': '6XX LAMBERT AVE',
#    'locationid': '40225',
#    'neighbourhood': 'Harewood',
#    'neighbourhoodid': '10',
#    'lat': '49.15483',
# ...
#    'long': '-124.002028'},
#   {'id': '4201201924849',
#    'file': '2019-24849',
#    'date': ['6/30/2019', '2:49:00', 'AM'],
#    'occurrencetype': 'Mischief - Loss of Enjoyment of Property',
#    'occurrencetypeid': '2170-05',
#    'crimetype': 'Mischief',
#    'crimetypeid': '2',
#    'crimecategory': 'Property Crime',
#    'crimecategoryid': '1',
#    'location': '31XX BARONS RD',
#    'locationid': '40401',
#    'neighbourhood': 'Rutherford',
#    'neighbourhoodid': '12',
#    'lat': '49.208165',
#    'long': '-124.002028'},
#   {'id': '4201201923899',
#    'file': '2019-23899',
#    'date': ['6/24/2019', '7:52:00', 'AM'],
#    'occurrencetype': 'Mischief - Loss of Enjoyment of Property',
#    'occurrencetypeid': '2170-05',
#    'crimetype': 'Mischief',
#    'crimetypeid': '2',
#    'crimecategory': 'Property Crime',
#    'crimecategoryid': '1',
#    'location': '31XX ISLAND HWY N',
#    'locationid': '40402',
#    'neighbourhood': 'Rutherford',
#    'neighbourhoodid': '12',
#    'lat': '49.204772',
#    'long': '-124.003575'},
#   {'id': '4201201917270',
#    'file': '2019-17270',
#    'date': ['5/12/2019', '4:34:00', 'PM'],
#    'occurrencetype': 'Mischief - Loss of Enjoyment of Property',
#    'occurrencetypeid': '2170-05',
#    'crimetype': 'Mischief',
#    'crimetypeid': '2',
#    'crimecategory': 'Property Crime',
#    'crimecategoryid': '1',
#    'location': '32XX NORWELL DR',
#    'locationid': '40410',
#    'neighbourhood': 'Rutherford',
#    'neighbourhoodid': '12',
#    'lat': '49.206311',
#    'long': '-124.002777'},
#   {'id': '4201201931352',
#    'file': '2019-31352',
#    'date': ['8/9/2019', '5:46:00', 'PM'],
#    'occurrencetype': 'Mischief - Loss of Enjoyment of Property',
#    'occurrencetypeid': '2170-05',
#    'crimetype': 'Mischief',
#    'crimetypeid': '2',
#    'crimecategory': 'Property Crime',
#    'crimecategoryid': '1',
#    'location': '37XX DEPARTURE BAY RD',
#    'locationid': '40427',
#    'neighbourhood': 'Rutherford',
#    'neighbourhoodid': '12',
#    'lat': '49.209815',
#    'long': '-123.994753'},
#   {'id': '4201201936158',
#    'file': '2019-36158',
#    'date': ['9/9/2019', '11:52:00', 'AM'],
#    'occurrencetype': 'Mischief - Loss of Enjoyment of Property',
#    'occurrencetypeid': '2170-05',
#    'crimetype': 'Mischief',
#    'crimetypeid': '2',
#    'crimecategory': 'Property Crime',
#    'crimecategoryid': '1',
#    'location': '40XX DEPARTURE BAY RD',
#    'locationid': '40444',
#    'neighbourhood': 'Rutherford',
#    'neighbourhoodid': '12',
#    'lat': '49.208807',
#    'long': '-123.998208'},
#   {'id': '4201201926116',
#    'file': '2019-26116',
#    'date': ['7/8/2019', '2:19:00', 'PM'],
#    'occurrencetype': 'Mischief - Loss of Enjoyment of Property',
#    'occurrencetypeid': '2170-05',
#    'crimetype': 'Mischief',
#    'crimetypeid': '2',
#    'crimecategory': 'Property Crime',
#    'crimecategoryid': '1',
#    'location': '40XX DEPARTURE BAY RD',
#    'locationid': '40444',
#    'neighbourhood': 'Rutherford',
#    'neighbourhoodid': '12',
#    'lat': '49.208807',
#    'long': '-123.998208'},
#   {'id': '4201201925184',
#    'file': '2019-25184',
#    'date': ['7/2/2019', '10:30:00', 'AM'],
#    'occurrencetype': 'Mischief - Loss of Enjoyment of Property',
#    'occurrencetypeid': '2170-05',
#    'crimetype': 'Mischief',
#    'crimetypeid': '2',
#    'crimecategory': 'Property Crime',
#    'crimecategoryid': '1',
#    'location': '40XX VICTORIA AVE',
#    'locationid': '40447',
#    'neighbourhood': 'Rutherford',
#    'neighbourhoodid': '12',
#    'lat': '49.207922',
#    'long': '-124.015407'},
#   {'id': '4201201940584',
#    'file': '2019-40584',
#    'date': ['10/8/2019', '5:22:00', 'AM'],
#    'occurrencetype': 'Mischief - Loss of Enjoyment of Property',
#    'occurrencetypeid': '2170-05',
#    'crimetype': 'Mischief',
#    'crimetypeid': '2',
#    'crimecategory': 'Property Crime',
#    'crimecategoryid': '1',
#    'location': '40XX WELLESLEY AVE',
#    'locationid': '40448',
#    'neighbourhood': 'Rutherford',
#    'neighbourhoodid': '12',
#    'lat': '49.208965',
#    'long': '-124.015728'},
#   {'id': '4201201914158',
#    'file': '2019-14158',
#    'date': ['4/21/2019', '8:59:00', 'PM'],
#    'occurrencetype': 'Mischief - Loss of Enjoyment of Property',
#    'occurrencetypeid': '2170-05',
#    'crimetype': 'Mischief',
#    'crimetypeid': '2',
#    'crimecategory': 'Property Crime',
#    'crimecategoryid': '1',
#    'location': '40XX WELLESLEY AVE',
#    'locationid': '40448',
#    'neighbourhood': 'Rutherford',
#    'neighbourhoodid': '12',
#    'lat': '49.208965',
#    'long': '-124.015728'},
#   {'id': '4201201940458',
#    'file': '2019-40458',
#    'date': ['10/7/2019', '9:37:00', 'AM'],
#    'occurrencetype': 'Mischief - Loss of Enjoyment of Property',
#    'occurrencetypeid': '2170-05',
#    'crimetype': 'Mischief',
#    'crimetypeid': '2',
#    'crimecategory': 'Property Crime',
#    'crimecategoryid': '1',
#    'location': '41XX DEPARTURE BAY RD',
#    'locationid': '40450',
#    'neighbourhood': 'Rutherford',
#    'neighbourhoodid': '12',
#    'lat': '49.207921',
#    'long': '-124.000486'},
#   {'id': '4201201918451',
#    'file': '2019-18451',
#    'date': ['5/20/2019', '6:16:00', 'PM'],
#    'occurrencetype': 'Mischief - Loss of Enjoyment of Property',
#    'occurrencetypeid': '2170-05',
#    'crimetype': 'Mischief',
#    'crimetypeid': '2',
#    'crimecategory': 'Property Crime',
#    'crimecategoryid': '1',
#    'location': '41XX DEPARTURE BAY RD',
#    'locationid': '40450',
#    'neighbourhood': 'Rutherford',
#    'neighbourhoodid': '12',
#    'lat': '49.207921',
#    'long': '-124.000486'},
#   {'id': '4201201938942',
#    'file': '2019-38942',
#    'date': ['9/27/2019', '12:46:00', 'AM'],
#    'occurrencetype': 'Mischief - Loss of Enjoyment of Property',
#    'occurrencetypeid': '2170-05',
#    'crimetype': 'Mischief',
#    'crimetypeid': '2',
#    'crimecategory': 'Property Crime',
#    'crimecategoryid': '1',
#    'location': '42XX DEPARTURE BAY RD',
#    'locationid': '40455',
#    'neighbourhood': 'Rutherford',
#    'neighbourhoodid': '12',
#    'lat': '49.206262',
#    'long': '-124.002542'},
#   {'id': '4201201928847',
#    'file': '2019-28847',
#    'date': ['7/25/2019', '4:10:00', 'AM'],
#    'occurrencetype': 'Mischief - Loss of Enjoyment of Property',
#    'occurrencetypeid': '2170-05',
#    'crimetype': 'Mischief',
#    'crimetypeid': '2',
#    'crimecategory': 'Property Crime',
#    'crimecategoryid': '1',
#    'location': '42XX DEPARTURE BAY RD',
#    'locationid': '40455',
#    'neighbourhood': 'Rutherford',
#    'neighbourhoodid': '12',
#    'lat': '49.206262',
#    'long': '-124.002542'},
#   {'id': '4201201919461',
#    'file': '2019-19461',
#    'date': ['5/27/2019', '8:56:00', 'AM'],
#    'occurrencetype': 'Mischief - Loss of Enjoyment of Property',
#    'occurrencetypeid': '2170-05',
#    'crimetype': 'Mischief',
#    'crimetypeid': '2',
#    'crimecategory': 'Property Crime',
#    'crimecategoryid': '1',
#    'location': '42XX DEPARTURE BAY RD',
#    'locationid': '40455',
#    'neighbourhood': 'Rutherford',
#    'neighbourhoodid': '12',
#    'lat': '49.206262',
#    'long': '-124.002542'},
#   {'id': '4201201918310',
#    'file': '2019-18310',
#    'date': ['5/19/2019', '1:44:00', 'PM'],
#    'occurrencetype': 'Mischief - Loss of Enjoyment of Property',
#    'occurrencetypeid': '2170-05',
#    'crimetype': 'Mischief',
#    'crimetypeid': '2',
#    'crimecategory': 'Property Crime',
#    'crimecategoryid': '1',
#    'location': '43XX GLENCRAIG DR',
#    'locationid': '40459',
#    'neighbourhood': 'Rutherford',
#    'neighbourhoodid': '12',
#    'lat': '49.219901',
#    'long': '-124.021081'},
#   {'id': '4201201923943',
#    'file': '2019-23943',
#    'date': ['6/24/2019', '11:46:00', 'AM'],
#    'occurrencetype': 'Mischief - Loss of Enjoyment of Property',
#    'occurrencetypeid': '2170-05',
#    'crimetype': 'Mischief',
#    'crimetypeid': '2',
#    'crimecategory': 'Property Crime',
#    'crimecategoryid': '1',
#    'location': '45XX UPLANDS DR',
#    'locationid': '40462',
#    'neighbourhood': 'Rutherford',
#    'neighbourhoodid': '12',
#    'lat': '49.219411',
#    'long': '-124.026112'},
#   {'id': '4201201931201',
#    'file': '2019-31201',
#    'date': ['8/8/2019', '5:06:00', 'PM'],
#    'occurrencetype': 'Mischief - Loss of Enjoyment of Property',
#    'occurrencetypeid': '2170-05',
#    'crimetype': 'Mischief',
#    'crimetypeid': '2',
#    'crimecategory': 'Property Crime',
#    'crimecategoryid': '1',
#    'location': '47XX RUTHERFORD RD',
#    'locationid': '40466',
#    'neighbourhood': 'Rutherford',
#    'neighbourhoodid': '12',
#    'lat': '49.215027',
#    'long': '-124.026734'},
#   {'id': '4201201922550',
#    'file': '2019-22550',
#    'date': ['6/15/2019', '10:11:00', 'PM'],
#    'occurrencetype': 'Mischief - Loss of Enjoyment of Property',
#    'occurrencetypeid': '2170-05',
#    'crimetype': 'Mischief',
#    'crimetypeid': '2',
#    'crimecategory': 'Property Crime',
#    'crimecategoryid': '1',
#    'location': '47XX RUTHERFORD RD',
#    'locationid': '40466',
#    'neighbourhood': 'Rutherford',
#    'neighbourhoodid': '12',
#    'lat': '49.215027',
#    'long': '-124.026734'},
#   {'id': '4201201940853',
#    'file': '2019-40853',
#    'date': ['10/9/2019', '2:29:00', 'PM'],
#    'occurrencetype': 'Mischief - Loss of Enjoyment of Property',
#    'occurrencetypeid': '2170-05',
#    'crimetype': 'Mischief',
#    'crimetypeid': '2',
#    'crimecategory': 'Property Crime',
#    'crimecategoryid': '1',
#    'location': '47XX RUTHERFORD RD',
#    'locationid': '40468',
#    'neighbourhood': 'Rutherford',
#    'neighbourhoodid': '12',
#    'lat': '49.216107',
#    'long': '-124.027078'},
#   {'id': '4201201918853',
#    'file': '2019-18853',
#    'date': ['5/23/2019', '5:46:00', 'AM'],
#    'occurrencetype': 'Mischief - Loss of Enjoyment of Property',
#    'occurrencetypeid': '2170-05',
#    'crimetype': 'Mischief',
#    'crimetypeid': '2',
#    'crimecategory': 'Property Crime',
#    'crimecategoryid': '1',
#    'location': '47XX RUTHERFORD RD',
#    'locationid': '40468',
#    'neighbourhood': 'Rutherford',
#    'neighbourhoodid': '12',
#    'lat': '49.216107',
#    'long': '-124.027078'},
#   {'id': '4201201931983',
#    'file': '2019-31983',
#    'date': ['8/13/2019', '10:31:00', 'PM'],
#    'occurrencetype': 'Mischief - Loss of Enjoyment of Property',
#    'occurrencetypeid': '2170-05',
#    'crimetype': 'Mischief',
#    'crimetypeid': '2',
#    'crimecategory': 'Property Crime',
#    'crimecategoryid': '1',
#    'location': '47XX UPLANDS DR',
#    'locationid': '40469',
#    'neighbourhood': 'Rutherford',
#    'neighbourhoodid': '12',
#    'lat': '49.22198',
#    'long': '-124.030492'},
#   {'id': '4201201938096',
#    'file': '2019-38096',
#    'date': ['9/21/2019', '3:52:00', 'PM'],
#    'occurrencetype': 'Mischief - Loss of Enjoyment of Property',
#    'occurrencetypeid': '2170-05',
#    'crimetype': 'Mischief',
#    'crimetypeid': '2',
#    'crimecategory': 'Property Crime',
#    'crimecategoryid': '1',
#    'location': '48XX CEDAR RIDGE PL',
#    'locationid': '40470',
#    'neighbourhood': 'Rutherford',
#    'neighbourhoodid': '12',
#    'lat': '49.215357',
#    'long': '-124.023577'},
#   {'id': '4201201935217',
#    'file': '2019-35217',
#    'date': ['9/3/2019', '8:07:00', 'AM'],
#    'occurrencetype': 'Mischief - Loss of Enjoyment of Property',
#    'occurrencetypeid': '2170-05',
#    'crimetype': 'Mischief',
#    'crimetypeid': '2',
#    'crimecategory': 'Property Crime',
#    'crimecategoryid': '1',
#    'location': '48XX RUTHERFORD RD',
#    'locationid': '40473',
#    'neighbourhood': 'Rutherford',
#    'neighbourhoodid': '12',
#    'lat': '49.214741',
#    'long': '-124.027491'},
#   {'id': '4201201915956',
#    'file': '2019-15956',
#    'date': ['5/3/2019', '12:44:00', 'PM'],
#    'occurrencetype': 'Mischief - Loss of Enjoyment of Property',
#    'occurrencetypeid': '2170-05',
#    'crimetype': 'Mischief',
#    'crimetypeid': '2',
#    'crimecategory': 'Property Crime',
#    'crimecategoryid': '1',
#    'location': '49XX SONGBIRD PL',
#    'locationid': '40476',
#    'neighbourhood': 'Rutherford',
#    'neighbourhoodid': '12',
#    'lat': '49.217431',
#    'long': '-124.024907'},
#   {'id': '4201201938265',
#    'file': '2019-38265',
#    'date': ['9/22/2019', '8:24:00', 'PM'],
#    'occurrencetype': 'Mischief - Loss of Enjoyment of Property',
#    'occurrencetypeid': '2170-05',
#    'crimetype': 'Mischief',
#    'crimetypeid': '2',
#    'crimecategory': 'Property Crime',
#    'crimecategoryid': '1',
#    'location': '49XX SONGBIRD PL',
#    'locationid': '40477',
#    'neighbourhood': 'Rutherford',
#    'neighbourhoodid': '12',
#    'lat': '49.218089',
#    'long': '-124.024971'},
#   {'id': '4201201926769',
#    'file': '2019-26769',
#    'date': ['7/12/2019', '1:45:00', 'PM'],
#    'occurrencetype': 'Mischief - Loss of Enjoyment of Property',
#    'occurrencetypeid': '2170-05',
#    'crimetype': 'Mischief',
#    'crimetypeid': '2',
#    'crimecategory': 'Property Crime',
#    'crimecategoryid': '1',
#    'location': '49XX WILLS RD',
#    'locationid': '40479',
#    'neighbourhood': 'Rutherford',
#    'neighbourhoodid': '12',
#    'lat': '49.215167',
#    'long': '-124.025756'},
#   {'id': '4201201917192',
#    'file': '2019-17192',
#    'date': ['5/12/2019', '3:01:00', 'AM'],
#    'occurrencetype': 'Mischief - Loss of Enjoyment of Property',
#    'occurrencetypeid': '2170-05',
#    'crimetype': 'Mischief',
#    'crimetypeid': '2',
#    'crimecategory': 'Property Crime',
#    'crimecategoryid': '1',
#    'location': '56XX TURNER RD',
#    'locationid': '40489',
#    'neighbourhood': 'Rutherford',
#    'neighbourhoodid': '12',
#    'lat': '49.230888',
#    'long': '-124.029825'},
#   {'id': '4201201914776',
#    'file': '2019-14776',
#    'date': ['4/26/2019', '12:26:00', 'AM'],
#    'occurrencetype': 'Mischief - Loss of Enjoyment of Property',
#    'occurrencetypeid': '2170-05',
#    'crimetype': 'Mischief',
#    'crimetypeid': '2',
#    'crimecategory': 'Property Crime',
#    'crimecategoryid': '1',
#    'location': '56XX TURNER RD',
#    'locationid': '40489',
#    'neighbourhood': 'Rutherford',
#    'neighbourhoodid': '12',
#    'lat': '49.230888',
#    'long': '-124.029825'},
#   {'id': '4201201938637',
#    'file': '2019-38637',
#    'date': ['9/25/2019', '10:27:00', 'AM'],
#    'occurrencetype': 'Mischief - Loss of Enjoyment of Property',
#    'occurrencetypeid': '2170-05',
#    'crimetype': 'Mischief',
#    'crimetypeid': '2',
#    'crimecategory': 'Property Crime',
#    'crimecategoryid': '1',
#    'location': '59XX CATHEDRAL CRES',
#    'locationid': '40505',
#    'neighbourhood': 'Rutherford',
#    'neighbourhoodid': '12',
#    'lat': '49.230942',
#    'long': '-124.033692'},
#   {'id': '4201201919038',
#    'file': '2019-19038',
#    'date': ['5/24/2019', '6:10:00', 'AM'],
#    'occurrencetype': 'Mischief - Loss of Enjoyment of Property',
#    'occurrencetypeid': '2170-05',
#    'crimetype': 'Mischief',
#    'crimetypeid': '2',
#    'crimecategory': 'Property Crime',
#    'crimecategoryid': '1',
#    'location': '59XX KADEN PL',
#    'locationid': '40506',
#    'neighbourhood': 'Rutherford',
#    'neighbourhoodid': '12',
#    'lat': '49.221859',
#    'long': '-124.029155'},
#   {'id': '4201201939412',
#    'file': '2019-39412',
#    'date': ['9/30/2019', '7:25:00', 'AM'],
#    'occurrencetype': 'Mischief - Loss of Enjoyment of Property',
#    'occurrencetypeid': '2170-05',
#    'crimetype': 'Mischief',
#    'crimetypeid': '2',
#    'crimecategory': 'Property Crime',
#    'crimecategoryid': '1',
#    'location': '63XX HAMMOND BAY RD',
#    'locationid': '40529',
#    'neighbourhood': 'Rutherford',
#    'neighbourhoodid': '12',
#    'lat': '49.234314',
#    'long': '-124.042045'},
#   {'id': '4201201928119',
#    'file': '2019-28119',
#    'date': ['7/20/2019', '6:23:00', 'PM'],
#    'occurrencetype': 'Mischief - Loss of Enjoyment of Property',
#    'occurrencetypeid': '2170-05',
#    'crimetype': 'Mischief',
#    'crimetypeid': '2',
#    'crimecategory': 'Property Crime',
#    'crimecategoryid': '1',
#    'location': 'ROSS RD / EMERALD DR',
#    'locationid': '40536',
#    'neighbourhood': 'Rutherford',
#    'neighbourhoodid': '12',
#    'lat': '49.211469',
#    'long': '-124.003122'},
#   {'id': '4201201940289',
#    'file': '2019-40289',
#    'date': ['10/5/2019', '7:45:00', 'PM'],
#    'occurrencetype': 'Mischief - Loss of Enjoyment of Property',
#    'occurrencetypeid': '2170-05',
#    'crimetype': 'Mischief',
#    'crimetypeid': '2',
#    'crimecategory': 'Property Crime',
#    'crimecategoryid': '1',
#    'location': '47XX UPLANDS DR',
#    'locationid': '41270',
#    'neighbourhood': 'Rutherford',
#    'neighbourhoodid': '12',
#    'lat': '49.221643',
#    'long': '-124.030327'}]}

# %%
crime_counter = co.defaultdict(int)
for crime in dat:
    crime_counter[crime['crimetype']] += 1
CL = crime_counter.items()
CLS = sorted(list(CL),key=op.itemgetter(1))

# %%
print("Top crimes",end='\n \n')
for crim,num in CLS[::-1]:
    print(crim+':',num)
# Out:
# Top crimes
#
# Mischief: 1391
# Theft from Motor Vehicle: 1277
# Theft: 730
# Shoplifting: 471
# Break and Enter: 401
# Theft of Motor Vehicle: 152

# %%
occurence_counter = co.defaultdict(int)
for crime in dat:
    occurence_counter[crime['occurrencetype']] += 1
OL = occurence_counter.items()
OLS = sorted(list(OL),key=op.itemgetter(1))
print("Top crimes",end='\n \n')
for crim,num in OLS[::-1]:
    print(crim+':',num)
# Out:
# Top crimes
#
# Theft from Motor Vehicle Under $5000: 1265
# Mischief Under $5000: 905
# Theft Other Under $5000: 568
# Mischief - Loss of Enjoyment of Property: 471
# Shoplifting Under $5000: 470
# Commercial Break and Enter: 185
# Residential Break and Enter: 141
# Theft Bicycle Under $5000: 133
# Other Break and Enter: 73
# Theft of Auto Under $5000: 44
# Theft of Truck Under $5000: 22
# Theft of Auto Over $5000: 22
# Theft of Motorcycle Under $5000: 18
# Take Auto Without Consent Under $5000: 13
# Theft of Truck Over $5000: 12
# Theft From Motor Vehicle Over $5000: 12
# Theft From Mail: 12
# Theft Other Over $5000: 10
# Mischief Over $5000: 8
# Mischief Caused by Act/Ommission: 7
# Theft of Other Vehicle Under $5000: 7
# Take Auto Without Consent Over $5000: 6
# Theft Bicycle Over $5000: 6
# Theft of Other Vehicle Over $5000: 4
# Theft of Motorcycle Over $5000: 4
# Seasonal Residence Break and Enter: 2
# Theft Electric/Gas/Telephone Under $5000: 1
# Shoplifting Over $5000: 1

# %%
for loc in nDat.keys():
    occurence_counter = co.defaultdict(int)
    for crime in nDat[loc]:
        occurence_counter[crime['occurrencetype']] += 1
    OL = occurence_counter.items()
    OLS = sorted(list(OL),key=op.itemgetter(1))
    print("Top crimes in "+loc,end='\n \n')
    for crim,num in OLS[::-1]:
        print(crim+':',num)
    print('-'*20,end='\n \n')
# Out:
# Top crimes in Westwood
#
# Theft from Motor Vehicle Under $5000: 33
# Mischief Under $5000: 15
# Theft Other Under $5000: 15
# Mischief - Loss of Enjoyment of Property: 9
# Theft Bicycle Under $5000: 5
# Other Break and Enter: 3
# Commercial Break and Enter: 3
# Residential Break and Enter: 2
# Theft of Truck Under $5000: 1
# Take Auto Without Consent Over $5000: 1
# --------------------
#
# Top crimes in Harewood
#
# Theft from Motor Vehicle Under $5000: 84
# Mischief Under $5000: 58
# Theft Other Under $5000: 45
# Shoplifting Under $5000: 36
# Mischief - Loss of Enjoyment of Property: 35
# Residential Break and Enter: 15
# Theft Bicycle Under $5000: 6
# Other Break and Enter: 6
# Theft of Truck Under $5000: 4
# Commercial Break and Enter: 4
# Theft of Auto Under $5000: 2
# Theft of Truck Over $5000: 2
# Theft of Auto Over $5000: 2
# Theft From Motor Vehicle Over $5000: 2
# Theft Other Over $5000: 2
# Mischief Caused by Act/Ommission: 1
# Mischief Over $5000: 1
# Theft of Motorcycle Under $5000: 1
# Theft of Other Vehicle Over $5000: 1
# Theft From Mail: 1
# Theft Bicycle Over $5000: 1
# --------------------
#
# Top crimes in Northfield
#
# Theft from Motor Vehicle Under $5000: 112
# Mischief Under $5000: 73
# Theft Other Under $5000: 49
# Mischief - Loss of Enjoyment of Property: 40
# Commercial Break and Enter: 35
# Shoplifting Under $5000: 31
# Theft Bicycle Under $5000: 15
# Residential Break and Enter: 13
# Other Break and Enter: 7
# Theft of Auto Under $5000: 4
# Theft of Motorcycle Under $5000: 3
# Take Auto Without Consent Under $5000: 2
# Mischief Over $5000: 1
# Theft of Truck Under $5000: 1
# Theft of Motorcycle Over $5000: 1
# Theft of Truck Over $5000: 1
# Theft of Auto Over $5000: 1
# Theft From Mail: 1
# Theft Other Over $5000: 1
# Seasonal Residence Break and Enter: 1
# --------------------
#
# Top crimes in Dover
#
# Shoplifting Under $5000: 67
# Theft from Motor Vehicle Under $5000: 57
# Mischief Under $5000: 43
# Theft Other Under $5000: 35
# Mischief - Loss of Enjoyment of Property: 28
# Theft Bicycle Under $5000: 4
# Residential Break and Enter: 4
# Commercial Break and Enter: 3
# Theft of Other Vehicle Under $5000: 1
# Theft of Motorcycle Under $5000: 1
# Theft of Auto Under $5000: 1
# Shoplifting Over $5000: 1
# Theft From Motor Vehicle Over $5000: 1
# Other Break and Enter: 1
# --------------------
#
# Top crimes in Pleasant Valley
#
# Shoplifting Under $5000: 58
# Theft from Motor Vehicle Under $5000: 47
# Theft Other Under $5000: 27
# Mischief Under $5000: 25
# Mischief - Loss of Enjoyment of Property: 10
# Commercial Break and Enter: 7
# Residential Break and Enter: 5
# Other Break and Enter: 4
# Theft Bicycle Under $5000: 3
# Take Auto Without Consent Under $5000: 2
# Theft of Auto Under $5000: 2
# Theft Other Over $5000: 2
# Take Auto Without Consent Over $5000: 1
# Theft of Other Vehicle Over $5000: 1
# Theft of Auto Over $5000: 1
# Theft From Mail: 1
# --------------------
#
# Top crimes in North Slope
#
# Theft from Motor Vehicle Under $5000: 13
# Mischief Under $5000: 9
# Residential Break and Enter: 4
# Theft Other Under $5000: 3
# Mischief - Loss of Enjoyment of Property: 2
# Theft of Truck Under $5000: 1
# Take Auto Without Consent Over $5000: 1
# --------------------
#
# Top crimes in Hammond Bay
#
# Mischief Under $5000: 15
# Theft from Motor Vehicle Under $5000: 10
# Theft Other Under $5000: 7
# Mischief - Loss of Enjoyment of Property: 4
# Theft of Auto Under $5000: 1
# Residential Break and Enter: 1
# Commercial Break and Enter: 1
# --------------------
#
# Top crimes in Unknown
#
# Theft from Motor Vehicle Under $5000: 1
# --------------------
#
# Top crimes in South End
#
# Mischief Under $5000: 76
# Theft from Motor Vehicle Under $5000: 65
# Theft Other Under $5000: 52
# Mischief - Loss of Enjoyment of Property: 37
# Shoplifting Under $5000: 15
# Commercial Break and Enter: 10
# Theft Bicycle Under $5000: 8
# Residential Break and Enter: 6
# Theft of Motorcycle Under $5000: 4
# Mischief Over $5000: 2
# Theft of Auto Under $5000: 2
# Theft of Auto Over $5000: 2
# Mischief Caused by Act/Ommission: 1
# Theft of Other Vehicle Under $5000: 1
# Theft of Truck Under $5000: 1
# Take Auto Without Consent Over $5000: 1
# Theft of Other Vehicle Over $5000: 1
# Theft of Truck Over $5000: 1
# Theft From Mail: 1
# --------------------
#
# Top crimes in Duke Pt
#
# Theft from Motor Vehicle Under $5000: 9
# Theft Other Under $5000: 8
# Mischief Under $5000: 7
# Theft of Truck Under $5000: 1
# Theft of Auto Under $5000: 1
# Theft of Truck Over $5000: 1
# Theft From Motor Vehicle Over $5000: 1
# Commercial Break and Enter: 1
# --------------------
#
# Top crimes in Departure Bay
#
# Theft from Motor Vehicle Under $5000: 63
# Mischief Under $5000: 41
# Theft Other Under $5000: 17
# Shoplifting Under $5000: 16
# Mischief - Loss of Enjoyment of Property: 13
# Theft Bicycle Under $5000: 7
# Other Break and Enter: 6
# Theft of Auto Under $5000: 4
# Theft of Auto Over $5000: 2
# Take Auto Without Consent Over $5000: 1
# Theft From Motor Vehicle Over $5000: 1
# Theft From Mail: 1
# Residential Break and Enter: 1
# Commercial Break and Enter: 1
# --------------------
#
# Top crimes in Linley Valley
#
# Theft from Motor Vehicle Under $5000: 41
# Mischief Under $5000: 18
# Mischief - Loss of Enjoyment of Property: 6
# Theft Other Under $5000: 5
# Residential Break and Enter: 5
# Theft Bicycle Under $5000: 2
# Other Break and Enter: 2
# Shoplifting Under $5000: 1
# Theft of Auto Under $5000: 1
# Take Auto Without Consent Over $5000: 1
# Theft From Motor Vehicle Over $5000: 1
# --------------------
#
# Top crimes in Newcastle/brechin
#
# Theft from Motor Vehicle Under $5000: 86
# Mischief Under $5000: 70
# Mischief - Loss of Enjoyment of Property: 39
# Theft Other Under $5000: 33
# Shoplifting Under $5000: 21
# Theft Bicycle Under $5000: 12
# Commercial Break and Enter: 12
# Residential Break and Enter: 11
# Other Break and Enter: 5
# Theft of Auto Under $5000: 2
# Theft From Mail: 2
# Mischief Over $5000: 1
# Theft of Other Vehicle Over $5000: 1
# Theft of Motorcycle Over $5000: 1
# Theft of Auto Over $5000: 1
# Seasonal Residence Break and Enter: 1
# --------------------
#
# Top crimes in University District
#
# Theft from Motor Vehicle Under $5000: 85
# Mischief Under $5000: 59
# Theft Other Under $5000: 39
# Mischief - Loss of Enjoyment of Property: 37
# Theft Bicycle Under $5000: 18
# Residential Break and Enter: 13
# Theft of Auto Under $5000: 6
# Theft of Auto Over $5000: 4
# Theft of Motorcycle Under $5000: 3
# Theft of Truck Under $5000: 3
# Theft From Mail: 3
# Theft of Other Vehicle Under $5000: 2
# Theft From Motor Vehicle Over $5000: 2
# Mischief Over $5000: 1
# Shoplifting Under $5000: 1
# Take Auto Without Consent Under $5000: 1
# Theft of Motorcycle Over $5000: 1
# Theft of Truck Over $5000: 1
# Theft Other Over $5000: 1
# Theft Bicycle Over $5000: 1
# Other Break and Enter: 1
# Commercial Break and Enter: 1
# --------------------
#
# Top crimes in Chase River
#
# Theft from Motor Vehicle Under $5000: 27
# Mischief Under $5000: 19
# Theft Other Under $5000: 19
# Other Break and Enter: 7
# Shoplifting Under $5000: 6
# Residential Break and Enter: 6
# Mischief - Loss of Enjoyment of Property: 3
# Theft Bicycle Under $5000: 3
# Commercial Break and Enter: 3
# Theft of Truck Over $5000: 2
# Theft of Auto Over $5000: 2
# Mischief Caused by Act/Ommission: 1
# Theft of Truck Under $5000: 1
# Theft of Auto Under $5000: 1
# Theft of Motorcycle Over $5000: 1
# --------------------
#
# Top crimes in Townsite
#
# Theft from Motor Vehicle Under $5000: 62
# Mischief Under $5000: 48
# Mischief - Loss of Enjoyment of Property: 36
# Theft Other Under $5000: 15
# Theft Bicycle Under $5000: 10
# Residential Break and Enter: 8
# Theft of Auto Under $5000: 4
# Commercial Break and Enter: 4
# Shoplifting Under $5000: 2
# Take Auto Without Consent Under $5000: 2
# Other Break and Enter: 2
# Theft of Other Vehicle Under $5000: 1
# Theft of Auto Over $5000: 1
# Theft Other Over $5000: 1
# --------------------
#
# Top crimes in Diver Lake
#
# Theft from Motor Vehicle Under $5000: 83
# Mischief Under $5000: 61
# Theft Other Under $5000: 42
# Shoplifting Under $5000: 34
# Mischief - Loss of Enjoyment of Property: 27
# Commercial Break and Enter: 22
# Other Break and Enter: 9
# Residential Break and Enter: 7
# Theft of Auto Under $5000: 4
# Theft Bicycle Under $5000: 3
# Theft of Truck Under $5000: 3
# Theft of Truck Over $5000: 2
# Theft From Motor Vehicle Over $5000: 2
# --------------------
#
# Top crimes in Downtown
#
# Theft from Motor Vehicle Under $5000: 290
# Mischief Under $5000: 216
# Theft Other Under $5000: 131
# Shoplifting Under $5000: 126
# Mischief - Loss of Enjoyment of Property: 108
# Commercial Break and Enter: 66
# Residential Break and Enter: 31
# Theft Bicycle Under $5000: 24
# Other Break and Enter: 15
# Theft of Auto Under $5000: 7
# Take Auto Without Consent Under $5000: 5
# Theft of Motorcycle Under $5000: 5
# Mischief Caused by Act/Ommission: 4
# Theft of Truck Under $5000: 4
# Theft of Auto Over $5000: 4
# Theft Other Over $5000: 3
# Theft Bicycle Over $5000: 3
# Theft of Other Vehicle Under $5000: 2
# Theft From Motor Vehicle Over $5000: 2
# Mischief Over $5000: 1
# Theft Electric/Gas/Telephone Under $5000: 1
# Theft of Truck Over $5000: 1
# Theft From Mail: 1
# --------------------
#
# Top crimes in Rutherford
#
# Theft from Motor Vehicle Under $5000: 97
# Shoplifting Under $5000: 56
# Mischief Under $5000: 52
# Mischief - Loss of Enjoyment of Property: 37
# Theft Other Under $5000: 26
# Theft Bicycle Under $5000: 13
# Commercial Break and Enter: 12
# Residential Break and Enter: 9
# Other Break and Enter: 5
# Theft of Truck Under $5000: 2
# Theft of Auto Under $5000: 2
# Theft of Auto Over $5000: 2
# Mischief Over $5000: 1
# Take Auto Without Consent Under $5000: 1
# Theft of Motorcycle Under $5000: 1
# Theft of Truck Over $5000: 1
# Theft From Mail: 1
# Theft Bicycle Over $5000: 1
# --------------------
